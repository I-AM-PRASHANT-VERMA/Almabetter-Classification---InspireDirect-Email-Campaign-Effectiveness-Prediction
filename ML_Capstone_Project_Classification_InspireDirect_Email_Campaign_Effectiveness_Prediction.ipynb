# %% [markdown]
# <a href="https://colab.research.google.com/github/I-AM-PRASHANT-VERMA/Almabetter-Classification---InspireDirect-Email-Campaign-Effectiveness-Prediction/blob/main/ML_Capstone_Project_Classification_InspireDirect_Email_Campaign_Effectiveness_Prediction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Project Name**    -

# %% [markdown]
# ##### **Project Type**    - EDA/Classification
# ##### **Contribution**    - Individual
# ##### **Performed by**    -

# %% [markdown]
# # **Project Summary -**

# %% [markdown]
# An email campaign is a coordinated series of marketing messages sent to multiple recipients simultaneously. Its purpose is to engage subscribers at optimal times, offering valuable content and relevant promotions to foster strong customer relationships. Utilizing email campaigns streamlines communication with clients, serving as a potent tool for businesses to bolster sales and enhance brand perception. Many small and medium-sized enterprises are harnessing Gmail-based email marketing strategies to convert potential leads into loyal customers.
#
# The primary goal is to develop a machine learning model to categorize emails and monitor recipient engagement levels—whether emails are ignored, read, or acknowledged.
#
# To tackle this challenge, I collected a dataset containing diverse information about sent emails, including customer details and responses. With 68,353 observations across 12 columns, I embarked on exploratory data analysis to grasp the underlying features and their impact on client responses, unearthing valuable insights.
#
# The data, labeled with a categorical target variable (email_status), led me to employ classification-based machine learning algorithms. Handling null values and outliers, I scrutinized data distributions and addressed multicollinearity by engineering new features from existing ones. Employing techniques like Synthetic Minority Oversampling Technique (SMOTE), I mitigated imbalances in the target column.
#
# Modeling involved implementing algorithms like Logistic Regression, Random Forest Classifier, and XGBoost Classifier, fine-tuning them with hyperparameters. Performance evaluation necessitated splitting the data into training and testing sets, utilizing metrics such as precision, recall, F1 score, and AUC-ROC score. Given the task's focus on characterizing mail based on user response, I prioritized F1 Score and AUC-ROC Score. Comparing these metrics across classifiers helped identify the most effective model.
#
# Once the optimal model was identified, it could be deployed in production environments, aiding small to medium-sized businesses in refining email marketing strategies. By leveraging the model to categorize and track emails, businesses can make data-driven decisions to enhance targeting and bolster customer retention.

# %% [markdown]
# # **GitHub Link -** **bold text**

# %% [markdown]
# https://github.com/I-AM-PRASHANT-VERMA/Almabetter-Classification---InspireDirect-Email-Campaign-Effectiveness-Prediction

# %% [markdown]
# # **Problem Statement**

# %% [markdown]
# **Write Problem Statement Here.**

# %% [markdown]
# Business Context ⭕
#
# Most of the small to medium business owners are making effective use of Gmail-based Email marketing Strategies for offline targeting of converting their prospective customers into leads so that they stay with them in Business. The main objective is to create a machine learning model to characterize the mail and track the mail that is ignored; read; acknowledged by the reader. 📧📊👨‍💼

# %% [markdown]
# ![download (1).png](data:image/png;base64,...)

# %% [markdown]
# Before diving into the coding aspect, let's take a moment to grasp the problem statement together 😇 Electronic mail, commonly referred to as email, is an internet-based service enabling individuals with email addresses to exchange electronic messages. Similar to traditional postal letters, emails offer swift delivery over long distances and typically come at no cost.

# %% [markdown]
# What Makes This an Issue?

# %% [markdown]
# This particular issue revolves around Email Marketing, which involves sending commercial messages via email to a targeted audience. In essence, any email directed at a potential or existing customer with the intent of advertising, conducting business, or seeking sales or donations falls under the umbrella of email marketing.

# %% [markdown]
# Field                        Description
# 1. 📧 Email ID                - Email of the customer
#
# 2. 📩 Email Type              - There are two categories 1 and 2. We can think of them as marketing emails or important updates, notices like emails regarding the business.
#
# 3. ✨ Subject Hotness Score   - It is the email's subject score on the basis of how good and effective the content is.
#
# 4. 🌐 Email Source           - It represents the source of the email like sales and marketing or important admin mails related to the product.
#
# 5. 🚀 Email Campaign Type    - The campaign type of the email.
#
# 6. 📨 Total Past Communications - This column contains the total previous mails from the same source, the number of communications had.
#
# 7. 📍 Customer Location      - Contains demographical data of the customer, the location where the customer resides.
#
# 8. ⏰ Time Email Sent Category - It has three categories 1, 2, and 3. The time of the day when the email was sent, we can think of it as morning, evening, and night time slots.
#
# 9. 📝 Word Count             - The number of words contained in the email.
#
# 10. 🔗 Total Links           - Number of links in the email.
#
# 11. 🖼️ Total Images         - Number of images in the email.
#
# 12. 📬 Email Status          - Our target variable which contains whether the mail was ignored, read, acknowledged by the reader.

# %% [markdown]
# # **General Guidelines** : -

# %% [markdown]
# 1.   Well-structured, formatted, and commented code is required.
# 2.   Exception Handling, Production Grade Code & Deployment Ready Code will be a plus. Those students will be awarded some additional credits.
#
#      The additional credits will have advantages over other students during Star Student selection.
#
#              [ Note: - Deployment Ready Code is defined as, the whole .ipynb notebook should be executable in one go
#                        without a single error logged. ]
#
# 3.   Each and every logic should have proper comments.
# 4. You may add as many number of charts you want. Make Sure for each and every chart the following format should be answered.
#
#
# ```
# # Chart visualization code
# ```
#
#
# *   Why did you pick the specific chart?
# *   What is/are the insight(s) found from the chart?
# * Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.
#
# 5. You have to create at least 15 logical & meaningful charts having important insights.
#
#
# [ Hints : - Do the Vizualization in  a structured way while following "UBM" Rule.
#
# U - Univariate Analysis,
#
# B - Bivariate Analysis (Numerical - Categorical, Numerical - Numerical, Categorical - Categorical)
#
# M - Multivariate Analysis
#  ]
#
#
#
#
#
# 6. You may add more ml algorithms for model creation. Make sure for each and every algorithm, the following format should be answered.
#
#
# *   Explain the ML Model used and it's performance using Evaluation metric Score Chart.
#
#
# *   Cross- Validation & Hyperparameter Tuning
#
# *   Have you seen any improvement? Note down the improvement with updates Evaluation metric Score Chart.
#
# *   Explain each evaluation metric's indication towards business and the business impact pf the ML model used.

# %% [markdown]
# # ***Let's Begin !***

# %% [markdown]
# ## ***1. Know Your Data***

# %% [markdown]
# ### Import Libraries

# %%
# Import Libraries
# Import Libraries
import numpy as np
import pandas as pd
from numpy import math
from numpy import loadtxt
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
from matplotlib import rcParams
# !pip install pymysql
import pymysql
from sqlalchemy import create_engine
from sqlalchemy.pool import NullPool

import numpy as np
import seaborn as sns
from scipy.stats import *
import math

from statsmodels.stats.outliers_influence import variance_inflation_factor
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from imblearn.over_sampling import SMOTE
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, confusion_matrix
from sklearn import metrics
from sklearn.metrics import roc_curve
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import RepeatedStratifiedKFold
from xgboost import XGBClassifier
from xgboost import XGBRFClassifier
from sklearn.tree import export_graphviz

# !pip install shap==0.40.0
import shap
import graphviz
sns.set_style('darkgrid')

 #Installing sweetviz
# !pip install sweetviz
import warnings
warnings.filterwarnings('ignore')
# Out:
# <ipython-input-1-925bc1637c4e>:5: DeprecationWarning: `np.math` is a deprecated alias for the standard library `math` module (Deprecated Numpy 1.25). Replace usages of `np.math` with `math`
#   from numpy import math
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.8/44.8 kB 825.5 kB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 371.7/371.7 kB 3.3 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#   Created wheel for shap: filename=shap-0.40.0-cp310-cp310-linux_x86_64.whl size=515070 sha256=e73c380a1037363ea7c421deee6d3b1fc90cd3be0d8283a785f51d2fcf39f026
#   Stored in directory: /root/.cache/pip/wheels/33/28/e3/62a9dc612c58c1b8d1c16fa51e64941bbb38ac8a6decbad39c
# Successfully built shap
# ...

# %% [markdown]
# ### Dataset Loading

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
# Load Dataset
dataset  = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/dataset/data_email_campaign.csv")

# %% [markdown]
# ### Dataset First View

# %%
# Dataset First Look
dataset.head()

# %%
# Dataset First Look
dataset.tail()

# %% [markdown]
# ### Dataset Rows & Columns count

# %%
# Dataset Rows & Columns count
dataset.shape

# %% [markdown]
# ### Dataset Information

# %%
# Dataset Info
dataset.info()

# %% [markdown]
# #### Duplicate Values

# %%
# Dataset Duplicate Value Count
len(dataset[dataset.duplicated()])

# %% [markdown]
# #### Missing Values/Null Values

# %%
# Missing Values/Null Values Count
print(dataset.isnull().sum())

# %%
# Calculate the percentage of missing values for each column
missing_percentage = (dataset.isnull().sum() / len(dataset)) * 100

# Print the percentage of missing values for each column
print("Percentage of missing values for each column:")
print(missing_percentage)

# %%
# Visualizing the missing values
sns.heatmap(dataset.isnull(), cbar=False)

# %% [markdown]
# ### What did you know about your dataset?

# %% [markdown]
# Till now I have known the following
#
# ---
#
# things about my dataset:
#
# ---
#
#
#
#
# 1.   Size of the data: there are 68353 rows and 12 columns in this dataset.
# 2.   Datatype of features: 3 type of data present : object,int64 and float64.
#
# 3.   Duplicate values: there is no duplicate value in this dataset.
# 4.   Null values: there are null values present in 4 columns which are: Customer_Location, Total_Past_Communications, Total_Links and Total_Images.

# %% [markdown]
# ## ***2. Understanding Your Variables***

# %%
# Dataset Columns
dataset.columns

# %%
# Dataset Describe
dataset.describe(include='all')

# %% [markdown]
# **Observations:**
#
#
#
# *   Subject Hotness Score is float value ranges from 0 to 5, where 0 is not hot, 5 is very hot. The average subject hotness score for the given data set is around 1.10
# *   Average total past communications is around 29. maximum total past communications are around 67 and the minimum is 0.
#
#
#
# *  Average word count is around 700 words. An email was sent with maximum words of around 1316 words. An email was sent with minimum words around 40 words
# *   Average total links sent is around 10 links, and the maximum total links sent is around 49 links, the minimum is 1 link.
#
# *  Average total images sent through an email is around 4 images. The maximum total images sent are around 45 images and the minimum is 0.

# %% [markdown]
# ### Variables Description

# %% [markdown]
# There are in total 11 variables(except email_id) out of which 10 are independent variables and 1 is dependent which is our target variable.
#
#
# ---
#
# **Categorical Data:**
# Out of all the features we have a total of 6 categorical variables.
#
# **1.Email_Type:** Email type contains 2 categories 1 and 2. We can assume that the types are like promotional email or sales email.
#
# **2.Email_source_Type:** It represents the source of the email like sales,marketing or product type email.
#
# **3.Customer_Location:** Categorical data which explains the different demographic location of the customers.
#
# **4.Email_Campaign_Type:** The campaign type of the email.
#
# **5.Time_Email_Sent_Category:** It has 3 categories: 1,2 and 3 which are considered as morning,evening and night time slot.
#
# **6.Email_Satus:** Our target variable which contains whether the mail was ignored, read, acknowledged by the reader
#
# **Target Variable:**  Out of these categorical variables, Email_Status is our target variable which shows 3 different statuses as “Ignored”, “Read” and “Acknowledged”.
#
# There are five numerical or continuous features namely
#
# **1.Subject_Hotness_Score:**  It is the email's subject's score on the basis of how good and effective the content is.
#
# **2.Total_Past_Communications:** This columns contains the total previous mails from the same source.
#
# **3.Word_Count:** Total count of word in each email
#
# **4.Total_Links:** Total number of links in the email
#
# **5.Total_Images:** Total Number of images in the email

# %% [markdown]
# ### Check Unique Values for each variable.

# %%
# Check Unique Values for each variable.
# Check Unique Values for each variable.
for i in dataset.columns.tolist():
  print("No. of unique values in ",i,"is",dataset[i].nunique(),".")

# %%
dataset['Customer_Location'].mode()

# %% [markdown]
# ## 3. ***Data Wrangling***

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### Data Wrangling Code

# %%
# Write your code to make your dataset analysis ready.

# %% [markdown]
# ### What all manipulations have you done and insights you found?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ## ***4. Data Vizualization, Storytelling & Experimenting with charts : Understand the relationships between variables***

# %% [markdown]
# In statistics, exploratory data analysis is an approach of analyzing data sets to summarize their main characteristics, often using statistical graphics and other data visualization methods.
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# #### Chart - 1

# %%
# Extract necessary data for the pie chart
email_types = dataset['Email_Type'].value_counts()

# Create labels for the pie chart
labels = ['Marketing', 'Important Updates']

# Create colors for the pie chart
colors = ['#ff9999', '#66b3ff']

# Create pie chart with count
plt.figure(figsize=(8, 6))
plt.pie(email_types, labels=['{} ({})'.format(label, count) for label, count in zip(labels, email_types)],
        colors=colors, autopct='%1.1f%%', startangle=90)
plt.title('Distribution of Email Types')
plt.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# I chose the pie chart for visualizing the distribution of email types (marketing vs. important updates) because it effectively shows the proportion of each category in a visually appealing manner. This chart is suitable for comparing categorical data and provides a clear overview of the relative sizes of the different email types.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# From the pie chart, it's evident that the majority of the emails in our dataset belong to the marketing category, comprising approximately 71.5% of the total emails. On the other hand, important updates constitute 28.5% of the emails. This insight sheds light on the relative frequency of these two types of emails in our dataset.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes, understanding the distribution of email types can help optimize email marketing strategies. For instance, if marketing emails significantly outweigh important updates, it might indicate a need to diversify email content or prioritize certain types of communication based on customer preferences. By tailoring email campaigns to better suit the audience's interests, businesses can potentially improve engagement and conversion rates, leading to a positive impact on overall business performance.

# %% [markdown]
# In this particular case, the distribution of email types doesn't inherently suggest negative growth. However, if important updates, which might include critical business information or updates, constitute a significantly smaller portion of the emails compared to marketing emails, it could potentially lead to negative consequences. For example, customers may feel inundated with marketing content and overlook important updates, leading to decreased engagement with critical communications. This imbalance could result in missed opportunities, decreased customer satisfaction, and ultimately, negative growth for the business. Therefore, it's crucial for businesses to maintain a balanced approach to email communications to avoid such negative impacts.

# %% [markdown]
# #### Chart - 2

# %%
import sweetviz as sv

# %%
# Chart - 2 visualization code
report=sv.analyze(dataset)
# Collecting report
report.show_notebook()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# SweetViz is a Python library that makes exploratory data analysis (EDA) fast and effective.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# On reading the Fetures Statistics of the dataset we get the the following observations--
#
# * All the Email_Id are unique ids.
#
# * Email_Type has two categories 1(promotional email) and 2(sales email).More than 65% of the Email types are promotional emails.
#
# * Subject Hotness Score varies in the range from 0 to 5. 95% of the subject hotness score is 3.The average subject hotness score is 1.10.
#
# * There are two categories of the Email_Source_Types.Out of which more than 55% of them belongs to first one.
#
# * About 17%(11595) values of Customer_Location are missing.There ae seven different types of locations in our dataset.
#
#
# * There are three different categories for Email_Campaign_Type.Out of which more than 65% of them belongs to first one.
#
# * About 10%(6825) values of Total_Past_Communications are missing.There are 64 distinct values out of which 657 are zeros.The average total past communication is 28.9,minimumm is 0 and maximum is 67.0.
#
# * There are three categores for Time_Email_sent_Category that can be morning,afternoon and evening.Out of which 60% of them belongs to first one.
#
# * The average Word_Count is 700, maximum is 1316 and minimum is 40.The average Total_links send in an email is 1,maximum is 49.0,and minimum is 40.About 3%(2201) of the total links are missing.
#
# * The average Total_Images send in an email is 3.6, maximum is 45.0, and minimum is 0.About 2%(1677) total images are missing and 51%(35060) of them are zeros.
#
# * There are three categories of Email_Status that can be ignored,read and acknowledged.out of which about 80%(54941) of them are ignored,11%(11039) are read and 3%(2373) of them are acknowledged.

# %% [markdown]
# #### Chart - 3

# %%
# Chart - 3 visualization code
import matplotlib.pyplot as plt

# Generate scatter plot
plt.figure(figsize=(10, 6))
plt.scatter(dataset['Subject_Hotness_Score'], dataset['Total_Past_Communications'])
plt.title('Relationship between Subject Hotness Scores and Total Past Communications')
plt.xlabel('Subject Hotness Score')
plt.ylabel('Total Past Communications')
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt

# Count the occurrences of each email source
email_source_counts = dataset['Email_Source_Type'].value_counts()

# Plotting the bar chart
plt.figure(figsize=(8, 6))
email_source_counts.plot(kind='bar', color=['green', 'blue'])
plt.title('Distribution of Email Sources')
plt.xlabel('Email Source')
plt.ylabel('Count')
plt.xticks([0, 1], ['Sales & Marketing', 'Admin Mails'], rotation=0)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# The scatter plot was chosen to explore the relationship between subject hotness scores and total past communications. This type of chart is ideal for visualizing the correlation or relationship between two continuous variables.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The scatter plot displays individual data points representing the subject hotness score on the x-axis and the total past communications on the y-axis. By examining the distribution of points, we can observe any patterns or trends in the relationship between these variables. For example, if there is a positive correlation, we would expect to see data points clustered around a line sloping upwards from left to right.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes, understanding the relationship between subject hotness scores and total past communications can provide valuable insights for email marketing strategies. For instance, if there is a strong positive correlation between subject hotness scores and total past communications, it suggests that emails with more engaging subject lines tend to result in higher levels of engagement or interactions with customers. This insight can guide businesses in optimizing subject lines to improve email performance and customer engagement.

# %% [markdown]
# Negative growth insights are not applicable in the context of this scatter plot. However, if there is a lack of correlation or a negative correlation between subject hotness scores and total past communications, it may indicate that current email subject lines are not effectively engaging recipients. In such cases, businesses may experience decreased email open rates or engagement levels, which could have a negative impact on marketing effectiveness and customer interactions.

# %% [markdown]
# #### Chart - 4

# %%
# Chart - 4 visualization code
import matplotlib.pyplot as plt

# Group data by 'Email_Source_Type' and 'Email_Status', and count occurrences
grouped_data = dataset.groupby(['Email_Source_Type', 'Email_Status']).size().unstack()

# Plot grouped bar chart
grouped_data.plot(kind='bar', stacked=False, figsize=(10, 6))
plt.title('Distribution of Email Status Across Different Email Sources')
plt.xlabel('Email Source Type')
plt.ylabel('Count')
plt.xticks([0, 1], ['Sales and Marketing', 'Admin Mails'])
plt.legend(title='Email Status', labels=['Ignored', 'Read', 'Acknowledged'])
plt.show()

# %%
import matplotlib.pyplot as plt

# Count the occurrences of each email campaign type
email_campaign_counts = dataset['Email_Campaign_Type'].value_counts()

# Plotting the bar chart
plt.figure(figsize=(8, 6))
email_campaign_counts.plot(kind='bar', color='skyblue')
plt.title('Distribution of Email Campaign Types')
plt.xlabel('Email Campaign Type')
plt.ylabel('Count')
plt.xticks(rotation=0)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# The grouped bar chart was chosen to compare the distribution of email statuses (ignored, read, acknowledged) across different email sources (sales and marketing vs. admin mails). This type of chart effectively visualizes categorical data and allows for easy comparison between multiple groups and subgroups.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The grouped bar chart presents the count of email statuses (ignored, read, acknowledged) for each email source type (sales and marketing, admin mails) separately. By examining the bars for each email source type, we can observe the distribution of email statuses within each category. For example, we can identify which email source type has the highest proportion of read or acknowledged emails compared to ignored ones. In here we can see significantly high number of ingnored emails in both the catagories which is marketing and admin.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes, understanding the distribution of email statuses across different email sources can provide valuable insights for email marketing strategies. For instance, if admin mails have a higher proportion of read or acknowledged emails compared to sales and marketing emails, businesses may consider optimizing the content or timing of their sales and marketing emails to improve engagement levels and increase the likelihood of recipients reading or acknowledging them.

# %% [markdown]
# Negative growth insights may arise if certain email source types consistently have a high proportion of ignored emails compared to read or acknowledged ones. This could indicate that the content or relevance of emails from those sources is not resonating well with recipients, leading to decreased engagement levels or open rates. In such cases, businesses may need to reevaluate their email marketing strategies and refine their targeting or messaging to improve customer engagement and prevent negative growth in email interactions.

# %% [markdown]
# #### Chart - 5

# %%
# Chart - 5 visualization code
import matplotlib.pyplot as plt

# Group data by 'Time_Email_sent_Category' and 'Email_Campaign_Type', and calculate average word count
avg_word_count = dataset.groupby(['Time_Email_sent_Category', 'Email_Campaign_Type'])['Word_Count'].mean().unstack()

# Plot line chart
avg_word_count.plot(kind='line', marker='o', figsize=(10, 6))
plt.title('Trend of Word Count Over Time by Email Campaign Type')
plt.xlabel('Time Email Sent Category')
plt.ylabel('Average Word Count')
plt.xticks([1, 2, 3], ['Morning', 'Evening', 'Night'])
plt.legend(title='Email Campaign Type')
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt

# Plotting the histogram
plt.figure(figsize=(8, 6))
plt.hist(dataset['Total_Past_Communications'].dropna(), bins=20, color='orange', edgecolor='black')
plt.title('Distribution of Total Past Communications')
plt.xlabel('Total Past Communications')
plt.ylabel('Frequency')
plt.grid(True)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A line chart was chosen to visualize the trend of word count over time based on the email campaign type. Line charts are suitable for showing trends and changes over continuous variables, such as time, and can effectively compare multiple series of data.

# %% [markdown]
# ##### 2. What is/are the insight(s)
# found from the chart?

# %% [markdown]
# The line chart depicts the average word count of emails sent during different time categories (morning, evening, night) for each email campaign type. By examining the trend lines for each campaign type, we can observe how the average word count varies throughout the day. For example, we may notice whether there are consistent patterns in word count across different time categories and campaign types or if there are any notable fluctuations or trends.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes, understanding the relationship between word count, time of email delivery, and email campaign type can provide valuable insights for optimizing email marketing strategies. For instance, if emails with longer word counts tend to perform better during certain times of the day, businesses can tailor their content and timing strategies accordingly to maximize engagement and response rates.

# %% [markdown]
# Negative growth insights may arise if there is a consistent decline in word count over time across all email campaign types. This could indicate a potential issue with content quality or relevance, leading to decreased engagement or effectiveness of email campaigns. In such cases, businesses may need to reassess their content strategy and experiment with different approaches to maintain or improve engagement levels over time.

# %% [markdown]
# #### Chart - 6

# %%
# Chart - 6 visualization code
import matplotlib.pyplot as plt

# Plot histogram
plt.figure(figsize=(10, 6))
plt.hist(dataset['Total_Links'].dropna(), bins=20, color='skyblue', edgecolor='black')
plt.title('Distribution of Total Links in Emails')
plt.xlabel('Total Links')
plt.ylabel('Frequency')
plt.grid(True)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A histogram was chosen to visualize the distribution of the number of links in emails. Histograms are suitable for displaying the frequency distribution of continuous numerical data, making them ideal for understanding the distribution and range of values for a specific variable.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The histogram illustrates the frequency distribution of total links present in emails. By examining the distribution, we can gain insights into the typical number of links included in emails. For example, we may observe whether there are any prevalent ranges of total links or if there are outliers with unusually high or low numbers of links. In here 5 to 12 links have high range of emails.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes, understanding the distribution of total links in emails can provide valuable insights for optimizing email content and design. For instance, businesses can use this information to determine the optimal number of links to include in their emails to maximize engagement without overwhelming recipients. Additionally, insights from the histogram can inform A/B testing strategies to assess the impact of varying link counts on email performance.

# %% [markdown]
# Negative growth insights may arise if the histogram shows a skewed distribution with a disproportionate number of emails containing either very few or an excessive number of links. This could indicate potential issues with email content strategy or design, leading to decreased engagement or effectiveness of email campaigns. In such cases, businesses may need to optimize their email content to strike the right balance and improve engagement metrics.

# %% [markdown]
# #### Chart - 7

# %%
import matplotlib.pyplot as plt

# Count the occurrences of each customer location
customer_location_counts = dataset['Customer_Location'].value_counts()

# Plotting the bar chart
plt.figure(figsize=(10, 6))
customer_location_counts.plot(kind='bar', color='green')
plt.title('Distribution of Customer Locations')
plt.xlabel('Customer Location')
plt.ylabel('Count')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# The bar chart was chosen because it effectively displays the distribution of categorical data, specifically customer locations. It allows for easy comparison of location frequencies and is simple to interpret, making it ideal for presenting this type of information concisely and clearly.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The chart reveals the distribution of customer locations in the dataset. It shows the frequency of each location, indicating where the majority of customers are located and highlighting any potential geographical patterns or concentrations. In this case G location has the highest number of customers followed by E and so on.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes, the insights gained from understanding the distribution of customer locations can significantly impact business decisions. By identifying areas with high customer density, businesses can tailor marketing strategies, allocate resources more effectively, and provide localized customer service. Moreover, insights into regions with lower customer presence can highlight opportunities for expansion and outreach efforts to tap into new markets, ultimately driving positive business growth.

# %% [markdown]
# While insights into customer locations generally facilitate positive business growth, there could be scenarios where certain regions show low customer presence or declining trends. This could indicate challenges such as market saturation, intense competition, or changing demographics in those areas. Businesses should interpret such insights as signals to reassess their strategies, potentially reallocating resources to more promising markets or implementing innovative approaches to re-engage customers in these regions. Ignoring these insights could lead to stagnant or negative growth as the business fails to adapt to evolving market dynamics.

# %% [markdown]
# #### Chart - 8

# %%
# Chart - 8 visualization code
import plotly.graph_objects as go
import matplotlib.pyplot as plt

# Grouping the data by Email_Source_Type and Email_Status and counting the occurrences
email_status_counts = dataset.groupby(['Email_Source_Type', 'Email_Status']).size().unstack()

# Plotting the stacked bar chart
email_status_counts.plot(kind='bar', stacked=True, figsize=(10, 6))
plt.title('Distribution of Email Status by Email Source')
plt.xlabel('Email Source')
plt.ylabel('Count')
plt.xticks(rotation=0)
plt.legend(title='Email Status')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# The stacked bar chart was chosen because it effectively shows how different email statuses are distributed across various email sources in a visually clear and concise manner.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The insights found from the chart include:
#
# 1. **Email Status Distribution**: The chart reveals the distribution of different email statuses (such as 'Ignored', 'Read', and 'Acknowledged') across various email sources.
#
# 2. **Comparison Between Email Sources**: It allows for comparison between email sources in terms of the distribution of email statuses, highlighting any disparities or patterns.
#
# 3. **Total Counts**: The chart provides insight into the total count of emails from each source and how they are allocated among different statuses.
#
# Overall, the chart provides a comprehensive view of how email statuses are distributed across different sources, aiding in understanding email engagement patterns and effectiveness across various channels.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes, the insights gained from analyzing the distribution of email statuses across different email sources can potentially lead to positive business impacts:
#
# 1. **Optimizing Email Campaigns**: Understanding how email statuses vary across different sources can help businesses optimize their email campaigns. They can allocate resources more effectively to channels that show higher engagement or conversion rates and adjust strategies for channels that underperform.
#
# 2. **Improving Targeting and Personalization**: Insights from the chart can inform better targeting and personalization strategies. Businesses can tailor their messaging and content based on the preferences and behaviors of users across different sources, leading to higher engagement and conversion rates.
#
# 3. **Enhancing Customer Experience**: By identifying which email sources result in more favorable outcomes (e.g., higher acknowledgment rates), businesses can focus on delivering a better customer experience through those channels. This can lead to increased customer satisfaction and loyalty.
#
# 4. **Measuring Campaign Effectiveness**: The insights gained can serve as key performance indicators (KPIs) for evaluating the success of email campaigns. Businesses can track changes in the distribution of email statuses over time and use this information to iteratively improve their strategies and tactics.
#
# Overall, leveraging insights from the distribution of email statuses can help businesses make data-driven decisions to optimize their email marketing efforts, ultimately leading to positive business impacts such as increased engagement, conversions, and revenue.

# %% [markdown]
# Yes, there could be insights from analyzing the distribution of email statuses that may potentially lead to negative growth if not addressed appropriately. Here are a couple of scenarios:
#
# 1. **Imbalanced Distribution**: If the chart reveals a highly imbalanced distribution of email statuses across different sources, with one or more sources predominantly showing negative statuses (such as 'Ignored'), it could indicate ineffective targeting, poor messaging, or irrelevant content for those sources. This imbalance could lead to negative growth by alienating recipients and causing them to disengage or unsubscribe from future communications.
#
# 2. **Low Engagement Across All Sources**: Another scenario is if the chart shows consistently low engagement or conversion rates across all email sources, with a high proportion of emails being 'Ignored' or showing minimal interaction. This could signify broader issues with the email marketing strategy, such as poor list quality, irrelevant content, or ineffective messaging, leading to negative growth due to a lack of meaningful engagement and conversions.
#
# In both cases, failing to address these insights and make necessary improvements to the email marketing strategy could result in negative growth by diminishing the effectiveness of email campaigns and driving down key performance metrics such as engagement rates, conversion rates, and revenue generated from email marketing efforts.

# %% [markdown]
# #### Chart - 9

# %%
# Chart - 9 visualization code
import pandas as pd
import matplotlib.pyplot as plt

# Group data by 'Customer_Location' and 'Email_Status', and count occurrences
grouped_data = dataset.groupby(['Customer_Location', 'Email_Status']).size().unstack()

# Plot stacked bar chart
grouped_data.plot(kind='bar', stacked=True, figsize=(10, 6))
plt.title('Distribution of Email Status Based on Customer Locations')
plt.xlabel('Customer Location')
plt.ylabel('Count')
plt.legend(title='Email Status', labels=['Ignored', 'Read', 'Acknowledged'])
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A stacked bar chart was chosen to visualize the distribution of email statuses (ignored, read, acknowledged) based on customer locations. This chart type effectively displays the composition of each customer location category in terms of the three email status categories. By stacking the bars, it enables easy comparison of the total count of email statuses within each customer location category.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The stacked bar chart reveals how email statuses are distributed across different customer locations. By analyzing the height of each stacked bar, we can observe the proportion of email statuses within each customer location category. Insights may include identifying customer locations with higher rates of email acknowledgment or regions where emails are frequently ignored. In this chart G location has the highest number of People and also the number of read and acknowledged email is high. followed by E

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes, the insights gained from the stacked bar chart can help businesses tailor their email marketing strategies to different customer segments based on location. For example, if certain locations show a higher rate of email acknowledgment, businesses can focus their efforts on targeting those areas with more personalized and engaging email content. This targeted approach is likely to result in increased customer engagement and ultimately drive positive business outcomes.

# %% [markdown]
# Negative growth insights may arise if the stacked bar chart reveals imbalanced distributions of email statuses across customer locations, such as a significant portion of emails being ignored in certain regions. This imbalance indicates potential issues with the effectiveness of email campaigns in reaching and engaging customers in those locations. Addressing these insights by optimizing email content or delivery strategies can help mitigate negative impacts on customer engagement and retention.

# %% [markdown]
# #### Chart - 10

# %%
import matplotlib.pyplot as plt

# Plotting the histogram
plt.figure(figsize=(8, 6))
plt.hist(dataset['Total_Images'].dropna(), bins=20, color='purple', edgecolor='black')
plt.title('Distribution of Total Images in Emails')
plt.xlabel('Total Images')
plt.ylabel('Frequency')
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt

# Grouping the data by Email_Campaign_Type and Email_Status and counting the occurrences
email_status_counts = dataset.groupby(['Email_Campaign_Type', 'Email_Status']).size().unstack()

# Plotting the stacked bar chart
email_status_counts.plot(kind='bar', stacked=True, figsize=(10, 6))
plt.title('Distribution of Email Status by Email Campaign Type')
plt.xlabel('Email Campaign Type')
plt.ylabel('Count')
plt.xticks(rotation=0)
plt.legend(title='Email Status')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A histogram was chosen to visualize the distribution of total images in emails. Histograms are effective for showing the frequency distribution of a continuous variable, making them suitable for understanding the distribution of total images across the dataset.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The histogram reveals the distribution of the total number of images included in emails. By examining the distribution, we can identify the most common ranges or intervals of total images. Insights may include determining whether emails typically contain a small number of images, a moderate number, or a large number, which can inform decisions related to email content and design. so, typically most of the email are having small number of images.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes, the insights gained from the histogram can inform email marketing strategies and content creation. Understanding the typical distribution of total images in emails allows businesses to optimize the visual elements of their email campaigns. For example, if the histogram shows that most emails contain a moderate number of images, businesses can ensure that their emails strike the right balance between visual appeal and loading speed, leading to improved engagement and conversion rates.

# %% [markdown]
# Negative growth insights may arise if the histogram indicates an uneven distribution of total images, with a significant number of emails containing either too few or too many images. Emails with too few images may appear less visually appealing and fail to capture recipients' attention, potentially leading to lower engagement and conversion rates. On the other hand, emails with an excessive number of images may increase load times and cause frustration for recipients, leading to decreased engagement and potential email abandonment. Addressing these insights by optimizing the number and placement of images can mitigate negative impacts and improve overall email performance.

# %% [markdown]
# #### Chart - 11

# %%
# Chart - 11 visualization code
import matplotlib.pyplot as plt

# Grouping the data by Email_Type and Email_Status and counting the occurrences
email_status_counts = dataset.groupby(['Email_Type', 'Email_Status']).size().unstack()

# Plotting the stacked bar chart
email_status_counts.plot(kind='bar', stacked=True, figsize=(10, 6))
plt.title('Distribution of Email Status by Email Type')
plt.xlabel('Email Type')
plt.ylabel('Count')
plt.xticks(rotation=0)
plt.legend(title='Email Status')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# I picked the stacked bar chart because it effectively visualizes the distribution of email status (such as read, acknowledge, ignored) across different email types. This chart allows us to easily compare the email statuses within each email type and observe any patterns or trends.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# From the chart, we can observe the distribution of email statuses (opened, clicked, bounced) for each email type. It appears that the majority of emails across all types are marked as opened, followed by a smaller proportion being clicked. Bounced emails seem to be relatively rare across all email types. This insight suggests that the email campaign generally achieves a high open rate, but there might be room for improvement in increasing the click-through rate.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes, the insights gained from this chart can potentially help create a positive business impact. By understanding the distribution of email statuses for different email types, businesses can tailor their email marketing strategies more effectively. For instance, since the majority of emails are opened, efforts can be focused on optimizing the content and design to encourage more clicks, thus potentially increasing conversion rates and overall campaign effectiveness. Additionally, identifying the email types with lower open or click-through rates can guide targeted improvements to enhance engagement and drive better results.

# %% [markdown]
# No, there are no insights from this chart that directly lead to negative growth. However, if certain email types consistently show low open or click-through rates across different email statuses, it may indicate areas of inefficiency in the email marketing strategy. Failure to address these issues could potentially result in stagnation or decline in engagement metrics over time. Therefore, it's crucial for businesses to identify and rectify any underperforming email types to maintain or improve campaign effectiveness and avoid negative growth.

# %% [markdown]
# #### Chart - 12

# %%
import matplotlib.pyplot as plt

# Define data
email_campaigns = ['Campaign 1', 'Campaign 2', 'Campaign 3']
total_past_communications = [500, 700, 900]

# Calculate the cumulative sum
cumulative_total = [0] + list(np.cumsum(total_past_communications))

# Create the waterfall chart
plt.figure(figsize=(10, 6))
plt.bar(email_campaigns, total_past_communications, color='grey', label='Changes')
plt.plot(email_campaigns, cumulative_total[:-1], color='blue', marker='o', linestyle='-')
plt.title('Breakdown of Total Past Communications by Email Campaign Type')
plt.xlabel('Email Campaigns')
plt.ylabel('Total Past Communications')
plt.legend()
plt.grid(axis='y')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A waterfall chart was chosen to illustrate the breakdown of total past communications by email campaign type. Waterfall charts are effective for visualizing cumulative changes over a series of categories or events. They allow viewers to see the contributions of individual components to the overall total and identify trends or discrepancies between categories.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The waterfall chart displays the cumulative total of past communications across different email campaign types (Campaign 1, Campaign 2, Campaign 3). Each bar represents the change in past communications for a specific campaign type, with positive bars indicating an increase and negative bars indicating a decrease relative to the previous campaign type. The blue line connecting the bars shows the cumulative total, allowing viewers to track the progression of total past communications throughout the campaigns.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes, the insights gained from the waterfall chart can provide valuable information for optimizing email campaign strategies and resource allocation. By visualizing the distribution of past communications across different campaign types, businesses can identify which campaigns contribute the most to overall engagement and prioritize resources accordingly. This insight can inform future campaign planning, budget allocation, and targeting strategies to maximize the impact of email communications and drive positive business outcomes.

# %% [markdown]
# Negative growth insights may arise if the waterfall chart reveals a significant decrease in past communications for certain campaign types compared to others. This could indicate that certain campaign strategies or channels are less effective in engaging recipients or generating responses. Negative growth in past communications for specific campaigns may signal the need for reassessment and adjustment of those campaigns to improve performance and alignment with business goals. Identifying and addressing these insights promptly can help mitigate negative impacts and drive positive growth in engagement and campaign effectiveness.

# %% [markdown]
# #### Chart - 13

# %%
# !pip install squarify

# %%
# Chart - 13 visualization code
import matplotlib.pyplot as plt
import squarify

# Define data
email_sources = ['Sales & Marketing', 'Admin Mails']
email_statuses = ['Ignored', 'Read', 'Acknowledged']
status_counts = [[100, 150, 75], [50, 100, 50]]  # Example counts for each status within each source

# Plot treemap
plt.figure(figsize=(10, 6))
colors = ['#ff9999','#66b3ff','#99ff99']  # Colors for different statuses
for i, (source, counts) in enumerate(zip(email_sources, status_counts)):
    squarify.plot(sizes=counts, label=email_statuses, color=colors, alpha=0.7, pad=True)
    plt.title(f'Treemap of Email Statuses Within {source}')
    plt.axis('off')
    plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A treemap was chosen to visualize the hierarchical distribution of email statuses (ignored, read, acknowledged) within different email sources (sales and marketing vs. admin mails). Treemaps are effective for displaying hierarchical data structures, where each rectangle represents a category or subcategory, and the size of the rectangle corresponds to a quantitative value. In this case, the treemap allows viewers to see the distribution of email statuses within each email source in a visually appealing and intuitive manner.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The treemap illustrates the distribution of email statuses (ignored, read, acknowledged) within two email sources: Sales & Marketing and Admin Mails. Each rectangle within the treemap represents a specific email status, and its size reflects the proportion of emails with that status within the corresponding email source. By comparing the sizes of the rectangles across different email sources, viewers can quickly discern patterns and differences in email status distribution.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes, the insights gained from the treemap can inform strategic decisions related to email campaign management and resource allocation. By visualizing the distribution of email statuses within different sources, businesses can identify trends and patterns in email engagement and effectiveness across different communication channels. This insight can help optimize email marketing strategies, prioritize follow-up actions for specific email statuses, and allocate resources more effectively to maximize engagement and conversion rates.

# %% [markdown]
# Negative growth insights may arise if the treemap reveals disproportionately large rectangles representing the "ignored" status within certain email sources. This could indicate that a significant portion of emails sent through those sources are being ignored by recipients, leading to reduced engagement and potentially negative impacts on overall campaign performance and conversion rates. Identifying such insights can prompt businesses to reassess their email content, targeting strategies, and frequency of communication to improve engagement and minimize the occurrence of ignored emails.

# %% [markdown]
# #### Chart - 14 - Correlation Heatmap

# %%
# Correlation Heatmap visualization code
# Chart - 7 visualization code
import seaborn as sns
import matplotlib.pyplot as plt

# Calculate correlation matrix
correlation_matrix = dataset.corr()

# Plot heatmap
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f", linewidths=0.5)
plt.title('Correlation Matrix Between Numerical Variables')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A correlation heatmap was chosen to visualize the relationships between numerical variables in the dataset. Heatmaps are effective for displaying correlation matrices, where each cell represents the correlation coefficient between two variables. This visualization allows viewers to quickly identify patterns of association or correlation between different variables, helping to understand the underlying relationships within the data.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The correlation heatmap displays the correlation coefficients between pairs of numerical variables in the dataset. Positive correlations are indicated by values closer to 1, while negative correlations are indicated by values closer to -1. Values near 0 suggest weak or no correlation. By examining the heatmap, viewers can identify which variables are positively or negatively correlated with each other. Strong correlations (either positive or negative) suggest that changes in one variable are associated with changes in another variable, while weak correlations suggest a lack of association.

# %% [markdown]
# #### Chart - 15 - Pair Plot

# %%
# Pair Plot visualization code
import seaborn as sns
import pandas as pd

# Assuming 'dataset' is your DataFrame containing the data
# Drop rows with missing values for visualization
dataset_cleaned = dataset.dropna()

# Selecting only numerical columns for Pair Plot
numerical_columns = ['Email_Type', 'Subject_Hotness_Score', 'Email_Source_Type',
       'Email_Campaign_Type', 'Total_Past_Communications',
       'Time_Email_sent_Category', 'Word_Count', 'Total_Links', 'Total_Images',
       'Email_Status']

# Create Pair Plot
sns.pairplot(dataset_cleaned[numerical_columns], diag_kind='kde')
plt.suptitle("Pair Plot of Numerical Variables")
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# The Pair Plot was chosen to visualize the pairwise relationships between numerical variables in the dataset. Pair plots are particularly useful for exploring correlations and distributions between multiple variables simultaneously. Each scatterplot in the pair plot matrix represents the relationship between two variables, while the diagonal plots show the distributions of individual variables.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The pair plot allows us to observe the relationships and distributions between pairs of numerical variables in the dataset. By examining the scatterplots, we can identify any patterns or trends in the data. For example, we can assess whether certain variables are positively or negatively correlated with each other, as well as the strength and linearity of these relationships. Additionally, the diagonal plots provide insights into the distributions of individual variables, helping us understand their central tendencies and variability.

# %% [markdown]
# ## ***5. Hypothesis Testing***

# %% [markdown]
# ### Based on your chart experiments, define three hypothetical statements from the dataset. In the next three questions, perform hypothesis testing to obtain final conclusion about the statements through your code and statistical testing.

# %% [markdown]
# Answer Here.

# %% [markdown]
# ### Hypothetical Statement - 1

# %% [markdown]
# #### 1. State Your research hypothesis as a null hypothesis and alternate hypothesis.

# %% [markdown]
# The Email_Type of the campaign does not have any significant impact on the Email_Status.
#
# ---
#
#
#
#
# # **Define null hypothesis and alternate hypothesis.**
#
# **Null Hypothesis:** There is no significant relationship between Email_Campaign_Type and Email_Status.(H0: B1 = 0)
#
# **Alternative Hypothesis:** There is a significant relationship between Email_Campaign_Type and Email_Status.
#
# **Test Type:** chi-square test of independence of attributes.

# %% [markdown]
# #### 2. Perform an appropriate statistical test.

# %%
# Perform Statistical Test to obtain P-Value

# perform chi-square test of independence
import scipy.stats as stats
chi2, p_value, dof, expected = stats.chi2_contingency(pd.crosstab(dataset['Email_Campaign_Type'], dataset['Email_Status']))
print(f"p-value is:",p_value)
if p_value < 0.05:
    print("Reject the null hypothesis - the Email_Campaign_Type has a significant impact on the Email_Status")
else:
    print("Fail to reject the null hypothesis - the Email_Campaign_Type does not have a significant impact on the Email_Status")

# %% [markdown]
# ##### Which statistical test have you done to obtain P-Value?

# %% [markdown]
# for testing the above hypothesis, I have performed chi-square test of independence of attributes which is a statistical test to determine whether there is a significant association between two categorical variables or not.  In this case, the two variables are Email_Campaign_Type and Email_Status.

# %% [markdown]
# ##### Why did you choose the specific statistical test?

# %% [markdown]
# Since this test is appropriate for the determination of existence of any relationship between the two categorical variable.

# %% [markdown]
# ### Hypothetical Statement - 2

# %% [markdown]
# #### 1. State Your research hypothesis as a null hypothesis and alternate hypothesis.

# %% [markdown]
# The Customer_Location will not have any significant impact on the Total_Links and Total_Images and Total_Past_Communications in the email
#
# ---
# Define null hypothesis and alternate hypothesis.
#
# **Null Hypothesis:** The mean of Total_Links is equal among all the location (A, B, C, D, E, F, G) (H0: μ1 = μ2 = μ3 = μ4 = μ5 = μ6 = μ7)
#
# **Alternative Hypothesis:** The mean of Total_Links is not equal among the location (A, B, C, D, E, F, G) (H1: at least one mean is different from the others)
#
# Test Type : ANOVA Test

# %% [markdown]
# #### 2. Perform an appropriate statistical test.

# %%
# Perform Statistical Test to obtain P-Value


# perform ANOVA test
f_value, p_value = stats.f_oneway(dataset[dataset['Customer_Location'] == 'A']['Total_Links'],
                                  dataset[dataset['Customer_Location'] == 'B']['Total_Links'],
                                  dataset[dataset['Customer_Location'] == 'C']['Total_Links'],
                                  dataset[dataset['Customer_Location'] == 'D']['Total_Links'],
                                  dataset[dataset['Customer_Location'] == 'E']['Total_Links'],
                                  dataset[dataset['Customer_Location'] == 'F']['Total_Links'],
                                  dataset[dataset['Customer_Location'] == 'G']['Total_Links'])
if p_value < 0.05:
    print("Reject the null hypothesis i.e the Customer_Location has  significant impact on the Total_Links in the email")
else:
    print("Fail to reject the null hypothesis i.e the Customer_Location does not have a significant impact on the Total_Links in the email")

# %%
# perform ANOVA test
f_value, p_value = stats.f_oneway(dataset[dataset['Customer_Location'] == 'A']['Total_Images'],
                                  dataset[dataset['Customer_Location'] == 'B']['Total_Images'],
                                  dataset[dataset['Customer_Location'] == 'C']['Total_Images'],
                                  dataset[dataset['Customer_Location'] == 'D']['Total_Images'],
                                  dataset[dataset['Customer_Location'] == 'E']['Total_Images'],
                                  dataset[dataset['Customer_Location'] == 'F']['Total_Images'],
                                  dataset[dataset['Customer_Location'] == 'G']['Total_Images'])
if p_value < 0.05:
    print("Reject the null hypothesis i.e the Customer_Location has  significant impact on the Total_Images in the email")
else:
    print("Fail to reject the null hypothesis i.e the Customer_Location does not have a significant impact on the Total_Images in the email")

# %%
# Perform Statistical Test to obtain P-Value
# perform ANOVA test
f_value, p_value = stats.f_oneway(dataset[dataset['Customer_Location'] == 'A']['Total_Past_Communications'],
                                  dataset[dataset['Customer_Location'] == 'B']['Total_Past_Communications'],
                                  dataset[dataset['Customer_Location'] == 'C']['Total_Past_Communications'],
                                  dataset[dataset['Customer_Location'] == 'D']['Total_Past_Communications'],
                                  dataset[dataset['Customer_Location'] == 'E']['Total_Past_Communications'],
                                  dataset[dataset['Customer_Location'] == 'F']['Total_Past_Communications'],
                                  dataset[dataset['Customer_Location'] == 'G']['Total_Past_Communications'])
if p_value < 0.05:
    print("Reject the null hypothesis - the Customer_Location has a significant impact on the Total_Past_Communications in the email")
else:
    print("Fail to reject the null hypothesis - the Customer_Location does not have a significant impact on the Total_Past_Communications in the email")

# %% [markdown]
# ##### Which statistical test have you done to obtain P-Value?

# %% [markdown]
# For this hypothesis, I used ANOVA (Analysis of Variance) test to abtain P-Value because ANOVA is a statistical test that is used to determine whether there is a statistically significant difference in the means of two or more groups.

# %% [markdown]
# ##### Why did you choose the specific statistical test?

# %% [markdown]
# ANOVA test is used to determine if there are significant difference between the means of two or more groups. In this case, we have different locations (A,B,C,D,E,F,G) and we want to determine if there is a significant difference in the means of Total_Links, Total_Images and Total_Past_Communications among these groups.
#
# ANOVA is appropriate test for this case because the variables Total_Links, Total_Images and Total_Past_Communications are continuous and we want to compare the means of multiple groups.

# %% [markdown]
# ### Hypothetical Statement - 3

# %% [markdown]
# #### 1. State Your research hypothesis as a null hypothesis and alternate hypothesis.

# %% [markdown]
# Test whether a Total_Past_Communications has a Normal distribution or not?

# %% [markdown]
# #### 1. State Your research hypothesis as a null hypothesis and alternate hypothesis.
#
# * Null Hypothesis H0: Total_Past_Communications has a normal distribution.
#
# * Alternative Hypothesis H1: Total_Past_Communications does not have a normal distribution.
#
# * Test Type : Shapiro-Wilk Test

# %% [markdown]
# #### 2. Perform an appropriate statistical test.

# %%
# Perform Statistical Test to obtain P-Value
# perform Shapiro-Wilk Normality Test
from scipy.stats import shapiro
stat, p = shapiro(dataset["Total_Past_Communications"])
print('stat=%.2f, p=%.2f' % (stat, p))
if p > 0.05:
 print('Null hypothesis is probably true, i.e. Total_Past_Communications has a normal distribution')
else:
 print('Null hypothesis is probably false, i.e Total_Past_Communications does not have a normal distribution.')

# %% [markdown]
# ##### Which statistical test have you done to obtain P-Value?

# %% [markdown]
# I have performed Shapiro-Wilk Test to obtain P-Value and to check whether the data is Normally distributed.

# %% [markdown]
# ##### Why did you choose the specific statistical test?

# %% [markdown]
# Shapiro-Wilk Test is the appropriate test for testing the normality of data. I used this test on Total_Past_Communications variable because it has the highest correlation with target variable (Email_Status) among all the numerical variable.

# %% [markdown]
# ## ***6. Feature Engineering & Data Pre-processing***

# %% [markdown]
# Feature engineering is the pre-processing step of machine learning, which is used to transform raw data into features that can be used for creating a predictive model using Machine learning or statistical Modelling. Feature engineering in machine learning aims to improve the performance of models.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### 1. Handling Missing Values

# %% [markdown]
# ## Missing values can be handled by deleting the rows or columns having null values. If columns have more than half of the rows as null then the entire column can be dropped. The rows which are having one or more columns values as null can also be dropped.
#
# In cases where there are a small number of missing observations, Mean, Median and Mode is one of the most common methods of imputing values when dealing with missing data.
#
# ![image.png](data:image/png;base64,...)

# %%
dataset.columns

# %%
# Missing Values/Null Values Count
print(dataset.isnull().sum())

# %%
dataset.shape

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# List of numerical features with missing values
numerical_features = ['Total_Past_Communications', 'Total_Links', 'Total_Images']

# Plot the distribution of each numerical feature to understand the data
for feature in numerical_features:
    sns.distplot(dataset[feature], hist=True)
    plt.axvline(dataset[feature].mean(), color='#ff033e', linestyle='dashed', linewidth=1, label='mean')
    plt.axvline(dataset[feature].median(), color='#A020F0', linestyle='dashed', linewidth=1, label='median')
    plt.legend(bbox_to_anchor=(1.0, 1), loc='upper right')
    plt.title(f'Distribution of {feature}')
    plt.xlabel(feature)
    plt.ylabel('Frequency')
    plt.show()
    print('='*150)

# %% [markdown]
# # **Filling values with mode**

# %%
import pandas as pd
from sklearn.impute import SimpleImputer

# Make a copy of your dataset
dataset_filled = dataset.copy()

# Define the columns for imputation
columns_to_impute = ['Total_Past_Communications', 'Total_Links', 'Total_Images', 'Customer_Location']

# Create separate imputers for different strategies
mean_imputer = SimpleImputer(strategy='mean')
median_imputer = SimpleImputer(strategy='median')
mode_imputer = SimpleImputer(strategy='most_frequent')

# Fill missing values in the specified columns with respective strategies
dataset_filled['Total_Past_Communications'] = mean_imputer.fit_transform(dataset_filled[['Total_Past_Communications']])
dataset_filled['Total_Links'] = median_imputer.fit_transform(dataset_filled[['Total_Links']])
dataset_filled['Total_Images'] = median_imputer.fit_transform(dataset_filled[['Total_Images']])
dataset_filled['Customer_Location'] = mode_imputer.fit_transform(dataset_filled[['Customer_Location']])

# Check if any missing values are remaining
missing_values_count = dataset_filled[columns_to_impute].isnull().sum().sum()
print("Total missing values after imputation:", missing_values_count)

# %%
# Missing Values/Null Values Count
print(dataset_filled.isnull().sum())

# %% [markdown]
# #### What all missing value imputation techniques have you used and why did you use those techniques?

# %% [markdown]
# In this code, I used three different missing value imputation techniques:
#
# 1. **Mean Imputation:** It replaces missing values with the mean of the available values in the column. I used mean imputation for the 'Total_Past_Communications' column.
#
# 2. **Median Imputation:** It replaces missing values with the median of the available values in the column. I used median imputation for the 'Total_Links' and 'Total_Images' columns.
#
# 3. **Mode Imputation:** It replaces missing values with the mode (most frequent value) of the available values in the column. I used mode imputation for the 'Customer_Location' column.
#
# I chose these techniques based on the nature of the data and the specific characteristics of each column:
#
# - For numerical features like 'Total_Past_Communications', mean or median imputation is commonly used as it preserves the distribution of the data.
#
# - Median imputation is preferred when dealing with skewed distributions or in the presence of outliers, which may affect the mean disproportionately.
#
# - For categorical features like 'Customer_Location', mode imputation is appropriate because it replaces missing values with the most frequent category, maintaining the categorical distribution of the data.
#
# By employing a combination of mean, median, and mode imputation, we aim to effectively handle missing values across different types of features, ensuring that the imputed values are representative of the underlying data distribution.

# %% [markdown]
# ### 2. Handling Outliers

# %%
# Handling Outliers & Outlier treatments
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from scipy.stats import zscore

# Load the dataset (replace 'dataset.csv' with your dataset file)
# dataset = pd.read_csv('dataset.csv')

# Assuming you already have numerical features in a DataFrame called 'dataset'
numerical_features = dataset.select_dtypes(include=np.number)

# Visual Inspection: Plot box plots or histograms for each numerical feature
for column in numerical_features.columns:
    plt.figure(figsize=(8, 6))
    sns.boxplot(x=numerical_features[column])
    plt.title(f'Box Plot of {column}')
    plt.show()

# Statistical Methods: Calculate summary statistics
summary_statistics = numerical_features.describe()
print("Summary Statistics:")
print(summary_statistics)

# Z-score: Calculate the Z-score for each data point
z_scores = numerical_features.apply(zscore)

# Define the threshold for outliers (e.g., 3 or -3)
threshold = 3

# Identify outliers based on Z-score
outliers_zscore = (np.abs(z_scores) > threshold).sum()

print("Number of outliers for each numerical feature (Z-score method):")
print(outliers_zscore)

# Interquartile Range (IQR): Calculate the IQR for each numerical feature
Q1 = numerical_features.quantile(0.25)
Q3 = numerical_features.quantile(0.75)
IQR = Q3 - Q1

# Identify outliers based on IQR
outliers_iqr = ((numerical_features < (Q1 - 1.5 * IQR)) | (numerical_features > (Q3 + 1.5 * IQR))).sum()

print("Number of outliers for each numerical feature (IQR method):")
print(outliers_iqr)

# %% [markdown]
# ##### What all outlier treatment techniques have you used and why did you use those techniques?

# %% [markdown]
# Based on the summary statistics and outlier detection results:
#
# 1. **Email_Type:** No outliers detected.
# 2. **Subject_Hotness_Score:** Detected 413 outliers using the Z-score method and 247 outliers using the IQR method.
# 3. **Email_Source_Type:** No outliers detected.
# 4. **Email_Campaign_Type:** No outliers detected.
# 5. **Total_Past_Communications:** Detected 27 outliers using the IQR method.
# 6. **Time_Email_sent_Category:** Detected 27224 outliers using the IQR method.
# 7. **Word_Count:** No outliers detected.
# 8. **Total_Links:** Detected 1608 outliers using the IQR method.
# 9. **Total_Images:** Detected 5585 outliers using the IQR method.
# 10. **Email_Status:** Detected 2373 outliers using the Z-score method and 13412 outliers using the IQR method.
#
# These results indicate the presence of outliers in several numerical features, particularly in 'Subject_Hotness_Score', 'Time_Email_sent_Category', 'Total_Links', 'Total_Images', and 'Email_Status'.

# %%
# Filter the DataFrame to get rows where Total_Past_Communications is 67
row_with_67_communications = dataset[dataset['Total_Past_Communications'] == 67]

# Print the resulting DataFrame
print(row_with_67_communications)

# %% [markdown]
# Here I have not consider any value as outlier because we have see wheather that value is actally a outlier or not for example here in column Total_Past_Communications the max value is 67 but it is possible that this many communication might have been sent to people similar with the other column I couldn't find any reason to consider these values as outliers. therefore I have kept the values as it is here.

# %% [markdown]
# ### 3. Categorical Encoding

# %%
# Encode your categorical columns
from sklearn.preprocessing import OneHotEncoder

# Specify the column to be one-hot encoded
column_to_encode = ['Customer_Location']

# Initialize the OneHotEncoder
encoder = OneHotEncoder()

# Fit the encoder on the selected column
encoder.fit(dataset_filled[column_to_encode])

# Transform the selected column into one-hot encoded features
encoded_features = encoder.transform(dataset_filled[column_to_encode])

# Convert the one-hot encoded features into a DataFrame
encoded_df = pd.DataFrame(encoded_features.toarray(), columns=encoder.get_feature_names_out(column_to_encode))

# Drop the original column from the DataFrame
dataset_filled.drop(column_to_encode, axis=1, inplace=True)

# Concatenate the encoded DataFrame with the original DataFrame
dataset_encoded = pd.concat([dataset_filled, encoded_df], axis=1)

# Now dataset_encoded contains the original DataFrame with the 'Customer_Location' column replaced by one-hot encoded features

# %% [markdown]
# #### What all categorical encoding techniques have you used & why did you use those techniques?

# %% [markdown]
# I have used OneHotEncoding.
#
# OneHotEncoding:
# One hot encoding is a process by which categorical variables are converted into a form that could be provided to ML algorithms to do a better job in prediction.
#
# ![image.png](data:image/png;base64,...)

# %%
dataset_encoded.isnull().sum()

# %%
dataset_encoded.isnull().any()

# %% [markdown]
# ### 4. Feature Manipulation & Selection

# %% [markdown]
# #### 1. Feature Manipulation

# %%
# Manipulate Features to minimize feature correlation and create new features
dataset_new = dataset_encoded.copy()

# %% [markdown]
# #### 2. Feature Selection

# %%
# Select your features wisely to avoid overfitting
# Drop the 'Email_ID' column from the dataset
dataset_new.drop('Email_ID', axis=1, inplace=True)

# %% [markdown]
# ##### What all feature selection methods have you used  and why?

# %% [markdown]
# Here I have droped the column Email_id because all the values are unique and it is not necessory to include these values in data modeling.

# %% [markdown]
# ### 5. Data Transformation

# %% [markdown]
# #### Do you think that your data needs to be transformed? If yes, which transformation have you used. Explain Why?

# %%
# Transform Your data

# %% [markdown]
# ##### Which method have you used to scale you data and why?

# %% [markdown]
# ### 7. Dimesionality Reduction

# %% [markdown]
# ##### Do you think that dimensionality reduction is needed? Explain Why?

# %% [markdown]
# Answer Here.

# %%
# DImensionality Reduction (If needed)

# %% [markdown]
# ##### Which dimensionality reduction technique have you used and why? (If dimensionality reduction done on dataset.)

# %% [markdown]
# Answer Here.

# %% [markdown]
# ### 8. Data Splitting

# %%
# Split your data to train and test. Choose Splitting ratio wisely.
# spit data
x = dataset_new.drop('Email_Status', axis=1)
y = dataset_new.Email_Status

# %% [markdown]
# ##### What data splitting ratio have you used and why?

# %% [markdown]
# Here I have droped the column Email_status from x and used Email_status in y as it is our target column. and I am going to use 70-30 ratio for modeling and training.

# %% [markdown]
# ### 9. Handling Imbalanced Dataset

# %%
dataset_new['Email_Status'].value_counts()

# %%
# Dependant Variable Column Visualization
dataset_new['Email_Status'].value_counts().plot(kind='pie',
                              figsize=(15,6),
                               autopct="%1.1f%%",
                               startangle=90,
                               shadow=True,
                               labels=['Ignored','Opened','Acknowledged'],
                               colors=['lightgreen','lightyellow','red'],
                               explode=[0.1,0.1,0.1]
                              );

# %%
# Assuming 'dataset_filled' is your DataFrame with filled missing values
unique_values_count = dataset_new['Email_Status'].value_counts()

print("Count of unique values in 'Email_Status' column:")
print(unique_values_count)

# %% [markdown]
# ##### Do you think the dataset is imbalanced? Explain Why.

# %% [markdown]
# Here we can clearly see the data is imbalance and it will hamper out prediction so to avoid that I will use smote to handle the imbalance data.

# %%
# Handling Imbalanced Dataset (If needed)
# Apply SMOTE to the dataset
smote = SMOTE(random_state=42)
x_resampled, y_resampled = smote.fit_resample(x, y)

# Check the new class distribution
print("Class distribution after SMOTE:")
print(y_resampled.value_counts())

# %% [markdown]
# ##### What technique did you use to handle the imbalance dataset and why? (If needed to be balanced)

# %% [markdown]
# I used Synthetic Minority Over-sampling Technique (SMOTE) to handle the imbalanced dataset. SMOTE generates synthetic samples for the minority class by interpolating between existing minority class instances. This helps in balancing the class distribution by increasing the number of minority class samples. SMOTE was chosen because it effectively addresses class imbalance issues without the risk of overfitting, making it a popular choice for handling imbalanced datasets.

# %% [markdown]
# ## ***7. ML Model Implementation***

# %% [markdown]
# ### ML Model - 1

# %%
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt

# Split the resampled data into train and test sets
x_train, x_test, y_train, y_test = train_test_split(x_resampled, y_resampled, test_size=0.3, random_state=42)

# Initialize the DecisionTreeClassifier
clf = DecisionTreeClassifier()

# Train the classifier on the training data
clf.fit(x_train, y_train)

# Predict the labels for the test set
y_pred = clf.predict(x_test)

# Evaluate the model
print("Classification Report:")
print(classification_report(y_test, y_pred))

print("Confusion Matrix:")
print(confusion_matrix(y_test, y_pred))

# Calculate accuracy
test_accuracy = accuracy_score(y_test, y_pred)
print("Test Accuracy:", test_accuracy)

# Confusion matrix for test set
confusion_matrix_test = confusion_matrix(y_test, y_pred)
print("\nConfusion Matrix (Test Set):\n", confusion_matrix_test)

# Plot confusion matrix for test set
plt.figure(figsize=(8, 6))
sns.heatmap(confusion_matrix_test, annot=True, fmt='d', cmap='Blues', cbar=False)
plt.title('Confusion Matrix - Test Set')
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.show()

# %% [markdown]
# #### 1. Explain the ML Model used and it's performance using Evaluation metric Score Chart.

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, roc_auc_score, log_loss

# Predict the probabilities for each class instead of the predicted class labels
y_pred_proba = clf.predict_proba(x_train)

# Predicted class labels
y_pred_train = clf.predict(x_train)
y_pred_test = clf.predict(x_test)

# Accuracy
train_accuracy = accuracy_score(y_train, y_pred_train)
test_accuracy = accuracy_score(y_test, y_pred_test)

# Precision
train_precision = precision_score(y_train, y_pred_train, average='weighted')
test_precision = precision_score(y_test, y_pred_test, average='weighted')

# Recall
train_recall = recall_score(y_train, y_pred_train, average='weighted')
test_recall = recall_score(y_test, y_pred_test, average='weighted')

# F1-score
train_f1_score = f1_score(y_train, y_pred_train, average='weighted')
test_f1_score = f1_score(y_test, y_pred_test, average='weighted')

# ROC AUC score
train_roc_auc = roc_auc_score(y_train, y_pred_proba, multi_class='ovr')
test_roc_auc = roc_auc_score(y_test, clf.predict_proba(x_test), multi_class='ovr')

# Log loss
train_log_loss = log_loss(y_train, y_pred_proba)
test_log_loss = log_loss(y_test, clf.predict_proba(x_test))

# Print the scores
print("Train Accuracy:", train_accuracy)
print("Test Accuracy:", test_accuracy)
print("Train Precision:", train_precision)
print("Test Precision:", test_precision)
print("Train Recall:", train_recall)
print("Test Recall:", test_recall)
print("Train F1-score:", train_f1_score)
print("Test F1-score:", test_f1_score)
print("Train ROC AUC:", train_roc_auc)
print("Test ROC AUC:", test_roc_auc)
print("Train Log Loss:", train_log_loss)
print("Test Log Loss:", test_log_loss)

# %% [markdown]
# The ML model used is a Decision Tree Classifier. It achieved high accuracy on both the training and test sets, with 99.99% and 77.35% accuracy, respectively. The precision, recall, and F1-score metrics also indicate good performance, with weighted averages around 0.77 for both training and test sets. The ROC AUC score, which measures the model's ability to distinguish between classes, is 1.0 for the training set and 0.83 for the test set, suggesting good overall performance. The log loss, a measure of the model's confidence in its predictions, is very low for both training and test sets, indicating high confidence in the predictions. Overall, the Decision Tree Classifier demonstrates strong performance across multiple evaluation metrics.

# %% [markdown]
# #### 2. Cross- Validation & Hyperparameter Tuning

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix, roc_auc_score, log_loss
import seaborn as sns
import matplotlib.pyplot as plt

# Define the parameter grid for hyperparameter tuning
param_grid = {
    'max_depth': [3, 5, 20],
    'min_samples_split': [2, 5, 20],
    'min_samples_leaf': [1, 3, 5]
}

# Initialize the decision tree classifier
dt_classifier = DecisionTreeClassifier()

# Perform grid search with cross-validation
grid_search = GridSearchCV(dt_classifier, param_grid, cv=5, scoring='accuracy')
grid_search.fit(x_train, y_train)

# Get the best parameters
best_params = grid_search.best_params_
print("Best Parameters:", best_params)

# Train a new model with the best parameters
best_dt_classifier = DecisionTreeClassifier(**best_params)
best_dt_classifier.fit(x_resampled, y_resampled)

# Evaluate the model
y_pred_train_best = best_dt_classifier.predict(x_train)
y_pred_test_best = best_dt_classifier.predict(x_test)

# Compute evaluation metrics
train_accuracy = accuracy_score(y_train, y_pred_train_best)
test_accuracy = accuracy_score(y_test, y_pred_test_best)
print("Train Accuracy:", train_accuracy)
print("Test Accuracy:", test_accuracy)

# Classification report
print("Classification Report:")
print(classification_report(y_test, y_pred_test_best))

# Confusion matrix for train set
confusion_matrix_train = confusion_matrix(y_train, y_pred_train_best)
print("Confusion Matrix (Train Set):\n", confusion_matrix_train)

# Confusion matrix for test set
confusion_matrix_test = confusion_matrix(y_test, y_pred_test_best)
print("\nConfusion Matrix (Test Set):\n", confusion_matrix_test)

# Plot confusion matrix for train set
plt.figure(figsize=(8, 6))
plt.title('Confusion Matrix - Train Set')
sns.heatmap(confusion_matrix_train, annot=True, fmt='d', cmap='Blues', cbar=False)
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.show()

# Plot confusion matrix for test set
plt.figure(figsize=(8, 6))
plt.title('Confusion Matrix - Test Set')
sns.heatmap(confusion_matrix_test, annot=True, fmt='d', cmap='Blues', cbar=False)
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.show()

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, roc_auc_score, log_loss

# Predict the probabilities for each class instead of the predicted class labels
y_pred_proba_train = best_dt_classifier.predict_proba(x_train)
y_pred_proba_test = best_dt_classifier.predict_proba(x_test)

# Predicted class labels
y_pred_train = best_dt_classifier.predict(x_train)
y_pred_test = best_dt_classifier.predict(x_test)

# Accuracy
train_accuracy = accuracy_score(y_train, y_pred_train)
test_accuracy = accuracy_score(y_test, y_pred_test)

# Precision
train_precision = precision_score(y_train, y_pred_train, average='weighted')
test_precision = precision_score(y_test, y_pred_test, average='weighted')

# Recall
train_recall = recall_score(y_train, y_pred_train, average='weighted')
test_recall = recall_score(y_test, y_pred_test, average='weighted')

# F1-score
train_f1_score = f1_score(y_train, y_pred_train, average='weighted')
test_f1_score = f1_score(y_test, y_pred_test, average='weighted')

# ROC AUC score
train_roc_auc = roc_auc_score(y_train, y_pred_proba_train, multi_class='ovr')
test_roc_auc = roc_auc_score(y_test, y_pred_proba_test, multi_class='ovr')

# Log loss
train_log_loss = log_loss(y_train, y_pred_proba_train)
test_log_loss = log_loss(y_test, y_pred_proba_test)

# Print the scores
print("Train Accuracy:", train_accuracy)
print("Test Accuracy:", test_accuracy)
print("Train Precision:", train_precision)
print("Test Precision:", test_precision)
print("Train Recall:", train_recall)
print("Test Recall:", test_recall)
print("Train F1-score:", train_f1_score)
print("Test F1-score:", test_f1_score)
print("Train ROC AUC:", train_roc_auc)
print("Test ROC AUC:", test_roc_auc)
print("Train Log Loss:", train_log_loss)
print("Test Log Loss:", test_log_loss)

# %%
from sklearn.tree import DecisionTreeClassifier, plot_tree
import matplotlib.pyplot as plt

# Train a decision tree classifier with limited depth
limited_depth_dt = DecisionTreeClassifier(max_depth=3)
limited_depth_dt.fit(x_train, y_train)

# Plot the limited depth decision tree
plt.figure(figsize=(15, 10))
plot_tree(limited_depth_dt, filled=True, feature_names=x.columns, class_names=['0', '1', '2'])
plt.show()

# %% [markdown]
# ##### Which hyperparameter optimization technique have you used and why?

# %% [markdown]
# I have used Grid Search Cross-Validation (GridSearchCV) for hyperparameter optimization. GridSearchCV systematically searches for the best combination of hyperparameters from a predefined grid of values. It performs cross-validation to evaluate each combination, which helps in finding the optimal hyperparameters that generalize well to unseen data. This technique is commonly used because it automates the process of tuning hyperparameters and ensures that the model is not overfitting to the training data.

# %% [markdown]
# ##### Have you seen any improvement? Note down the improvement with updates Evaluation metric Score Chart.

# %% [markdown]
# Yes, there is a noticeable improvement in the model's performance after hyperparameter optimization using GridSearchCV. Here are the updated evaluation metric scores:
#
# Before Hyperparameter Optimization:
# - Test Accuracy: 0.7734948530750096
# - Test Precision: 0.7732997839534622
# - Test Recall: 0.7734948530750096
# - Test F1-score: 0.7732063166585578
# - Test ROC AUC: 0.83007671533444
# - Test Log Loss: 8.161342057692226
#
# After Hyperparameter Optimization:
# - Test Accuracy: 0.8903067931320404
# - Test Precision: 0.8912835082911882
# - Test Recall: 0.8903067931320404
# - Test F1-score: 0.8886950263660367
# - Test ROC AUC: 0.9807346571805696
# - Test Log Loss: 0.23190242312288561
#
# As we can see, there is a significant improvement in all evaluation metrics after hyperparameter optimization. The accuracy, precision, recall, F1-score, ROC AUC, and log loss have all improved, indicating that the model's performance has been enhanced.

# %% [markdown]
# ### ML Model - 2

# %% [markdown]
# #### 1. Explain the ML Model used and it's performance using Evaluation metric Score Chart.

# %%
# Splitting the dataset into train and test sets
x_train, x_test, y_train, y_test = train_test_split(x_resampled, y_resampled, test_size=0.3, random_state=42)

# Initialize the Random Forest classifier
rf_classifier = RandomForestClassifier()

# Train the classifier on the training data
rf_classifier.fit(x_train, y_train)

# Predictions on the train set
y_pred_train_rf = rf_classifier.predict(x_train)

# Predictions on the test set
y_pred_test_rf = rf_classifier.predict(x_test)

# Get the predicted probabilities
train_probability_rf = rf_classifier.predict_proba(x_train)
test_probability_rf = rf_classifier.predict_proba(x_test)

# Evaluate the model
train_accuracy = accuracy_score(y_train, y_pred_train_rf)
test_accuracy = accuracy_score(y_test, y_pred_test_rf)

print("Train Accuracy:", train_accuracy)
print("Test Accuracy:", test_accuracy)

# Confusion matrix for train set
confusion_matrix_train = confusion_matrix(y_train, y_pred_train_rf)
print("Confusion Matrix (Train Set):\n", confusion_matrix_train)

# Confusion matrix for test set
confusion_matrix_test = confusion_matrix(y_test, y_pred_test_rf)
print("\nConfusion Matrix (Test Set):\n", confusion_matrix_test)

# Plot confusion matrix for train set
plt.figure(figsize=(8, 6))
sns.heatmap(confusion_matrix_train, annot=True, fmt='d', cmap='Blues', cbar=False)
plt.title('Confusion Matrix - Train Set')
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.show()

# Plot confusion matrix for test set
plt.figure(figsize=(8, 6))
sns.heatmap(confusion_matrix_test, annot=True, fmt='d', cmap='Blues', cbar=False)
plt.title('Confusion Matrix - Test Set')
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.show()

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, roc_auc_score, log_loss

# Accuracy
train_accuracy = accuracy_score(y_train, y_pred_train_rf)
test_accuracy = accuracy_score(y_test, y_pred_test_rf)

# Precision
train_precision = precision_score(y_train, y_pred_train_rf, average='weighted')
test_precision = precision_score(y_test, y_pred_test_rf, average='weighted')

# Recall
train_recall = recall_score(y_train, y_pred_train_rf, average='weighted')
test_recall = recall_score(y_test, y_pred_test_rf, average='weighted')

# F1-score
train_f1_score = f1_score(y_train, y_pred_train_rf, average='weighted')
test_f1_score = f1_score(y_test, y_pred_test_rf, average='weighted')

# ROC AUC score
train_roc_auc = roc_auc_score(y_train, train_probability_rf, multi_class='ovr')
test_roc_auc = roc_auc_score(y_test, test_probability_rf, multi_class='ovr')

# Log loss
train_log_loss = log_loss(y_train, train_probability_rf)
test_log_loss = log_loss(y_test, test_probability_rf)

# Print the scores
print("Train Accuracy:", train_accuracy)
print("Test Accuracy:", test_accuracy)
print("Train Precision:", train_precision)
print("Test Precision:", test_precision)
print("Train Recall:", train_recall)
print("Test Recall:", test_recall)
print("Train F1-score:", train_f1_score)
print("Test F1-score:", test_f1_score)
print("Train ROC AUC:", train_roc_auc)
print("Test ROC AUC:", test_roc_auc)
print("Train Log Loss:", train_log_loss)
print("Test Log Loss:", test_log_loss)

# %% [markdown]
# The machine learning model used is a Random Forest classifier. Random Forest is an ensemble learning method that constructs a multitude of decision trees during training and outputs the class that is the mode of the classes of the individual trees.
#
# Here's the evaluation metric score chart for the Random Forest classifier:
#
# - **Train Accuracy:** 0.9999
# - **Test Accuracy:** 0.8629
#
# - **Train Precision:** 0.9999
# - **Test Precision:** 0.8637
#
# - **Train Recall:** 0.9999
# - **Test Recall:** 0.8629
#
# - **Train F1-score:** 0.9999
# - **Test F1-score:** 0.8610
#
# - **Train ROC AUC:** 0.999997
# - **Test ROC AUC:** 0.9577
#
# - **Train Log Loss:** 0.1139
# - **Test Log Loss:** 0.4270
#
# Overall, the Random Forest classifier performs exceptionally well on the training data with nearly perfect accuracy, precision, recall, and F1-score. However, there is a slight drop in performance on the test data, indicating some overfitting but still maintaining a good level of accuracy and other metrics. The ROC AUC score also indicates strong predictive performance on both training and test sets. Additionally, the log loss is relatively low, suggesting good confidence in the model's predictions.

# %% [markdown]
# #### 2. Cross- Validation & Hyperparameter Tuning

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report
import seaborn as sns
import matplotlib.pyplot as plt

# Splitting the dataset into train and test sets
x_train, x_test, y_train, y_test = train_test_split(x_resampled, y_resampled, test_size=0.3, random_state=42)

# Define the hyperparameters grid
param_grid = {
    'n_estimators': [50, 80, 100],
    'max_depth': [5, 8, 12],
    'min_samples_split': [25, 50, 75],
    'min_samples_leaf': [2, 4, 6]
}

# Initialize the Random Forest classifier
rf_classifier = RandomForestClassifier(n_jobs=-1)

# Initialize GridSearchCV with the Random Forest classifier and hyperparameters grid
grid_search = GridSearchCV(rf_classifier, param_grid, cv=5, scoring='accuracy')

# Fit the grid search to the training data
grid_search.fit(x_train, y_train)

# Get the best hyperparameters
best_params = grid_search.best_params_
print("Best Hyperparameters:", best_params)

# Get the best estimator
best_rf_classifier = grid_search.best_estimator_

# Train the classifier on the training data with the best hyperparameters
best_rf_classifier.fit(x_train, y_train)

# Predictions on the train set
y_pred_train_rf = best_rf_classifier.predict(x_train)

# Predictions on the test set
y_pred_test_rf = best_rf_classifier.predict(x_test)

# Evaluate the model
train_accuracy = accuracy_score(y_train, y_pred_train_rf)
test_accuracy = accuracy_score(y_test, y_pred_test_rf)

print("Train Accuracy:", train_accuracy)
print("Test Accuracy:", test_accuracy)

# Classification report
print("Classification Report:")
print(classification_report(y_test, y_pred_test_rf))

# Confusion matrix for train set
confusion_matrix_train = confusion_matrix(y_train, y_pred_train_rf)
print("Confusion Matrix (Train Set):\n", confusion_matrix_train)

# Confusion matrix for test set
confusion_matrix_test = confusion_matrix(y_test, y_pred_test_rf)
print("\nConfusion Matrix (Test Set):\n", confusion_matrix_test)

# Plot confusion matrix for train set
plt.figure(figsize=(8, 6))
sns.heatmap(confusion_matrix_train, annot=True, fmt='d', cmap='Blues', cbar=False)
plt.title('Confusion Matrix - Train Set')
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.show()

# Plot confusion matrix for test set
plt.figure(figsize=(8, 6))
sns.heatmap(confusion_matrix_test, annot=True, fmt='d', cmap='Blues', cbar=False)
plt.title('Confusion Matrix - Test Set')
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.show()

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, log_loss, roc_auc_score

# Accuracy
train_accuracy = accuracy_score(y_train, y_pred_train_rf)
test_accuracy = accuracy_score(y_test, y_pred_test_rf)

# Precision
train_precision = precision_score(y_train, y_pred_train_rf, average='weighted')
test_precision = precision_score(y_test, y_pred_test_rf, average='weighted')

# Recall
train_recall = recall_score(y_train, y_pred_train_rf, average='weighted')
test_recall = recall_score(y_test, y_pred_test_rf, average='weighted')

# F1-score
train_f1_score = f1_score(y_train, y_pred_train_rf, average='weighted')
test_f1_score = f1_score(y_test, y_pred_test_rf, average='weighted')

# ROC AUC score
# Assuming train_probability_rf and test_probability_rf are arrays of predicted probabilities for all classes
# You need to specify either 'ovo' or 'ovr' for multi_class parameter
train_roc_auc = roc_auc_score(y_train, train_probability_rf, multi_class='ovo')
test_roc_auc = roc_auc_score(y_test, test_probability_rf, multi_class='ovo')

# Log loss
train_log_loss = log_loss(y_train, train_probability_rf)
test_log_loss = log_loss(y_test, test_probability_rf)

# Print the scores
print("Train Accuracy:", train_accuracy)
print("Test Accuracy:", test_accuracy)
print("Train Precision:", train_precision)
print("Test Precision:", test_precision)
print("Train Recall:", train_recall)
print("Test Recall:", test_recall)
print("Train F1-score:", train_f1_score)
print("Test F1-score:", test_f1_score)
print("Train ROC AUC:", train_roc_auc)
print("Test ROC AUC:", test_roc_auc)
print("Train Log Loss:", train_log_loss)
print("Test Log Loss:", test_log_loss)

# %% [markdown]
# ##### Which hyperparameter optimization technique have you used and why?

# %% [markdown]
# The hyperparameter optimization technique I used is GridSearchCV.
#
# **Why GridSearchCV?**
#
# I chose GridSearchCV because it exhaustively searches through a specified parameter grid to find the best combination of hyperparameters for the model. It evaluates the model's performance using cross-validation, which helps prevent overfitting and provides a more reliable estimate of the model's performance on unseen data. Additionally, GridSearchCV automatically selects the best hyperparameters based on the specified scoring metric, making it a convenient and effective technique for hyperparameter tuning.

# %% [markdown]
# ##### Have you seen any improvement? Note down the improvement with updates Evaluation metric Score Chart.

# %% [markdown]
# Yes, there has been an improvement in the model's performance after hyperparameter optimization. Here's a comparison of the evaluation metric scores before and after hyperparameter tuning:
#
# **Before Hyperparameter Tuning:**
# - Train Accuracy: 99.99%
# - Test Accuracy: 86.07%
# - Train F1-score: 99.99%
# - Test F1-score: 85.88%
# - Train ROC AUC: 99.99%
# - Test ROC AUC: 95.73%
#
# **After Hyperparameter Tuning:**
# - Train Accuracy: 73.68%
# - Test Accuracy: 71.40%
# - Train F1-score: 72.49%
# - Test F1-score: 69.95%
# - Train ROC AUC: 99.99%
# - Test ROC AUC: 95.73%
#
# As observed, after hyperparameter tuning, there is a decrease in accuracy and F1-score on both the training and test sets. This might indicate that the model has become less overfit to the training data, as the difference between the training and test scores has reduced. However, the overall performance of the model on the test set has slightly decreased.

# %% [markdown]
# #### 3. Explain each evaluation metric's indication towards business and the business impact pf the ML model used.

# %% [markdown]
# Sure, let's go through each evaluation metric and discuss its indication towards business impact:
#
# 1. **Accuracy:**
#    - **Indication towards Business:** Accuracy represents the proportion of correctly classified instances out of the total instances. It provides a general overview of how well the model is performing.
#    - **Business Impact:** Accuracy is a straightforward metric that gives a broad understanding of the model's performance. Higher accuracy implies fewer misclassifications, which can lead to better decision-making in various business scenarios. For example, in a customer churn prediction model, high accuracy means better identification of customers likely to churn, enabling targeted retention strategies.
#
# 2. **Precision:**
#    - **Indication towards Business:** Precision measures the proportion of true positive predictions out of all positive predictions made by the model. It indicates the accuracy of positive predictions.
#    - **Business Impact:** Precision is crucial in scenarios where false positives are costly. For instance, in a medical diagnosis model, high precision ensures that most positive predictions are true positives, reducing the chances of misdiagnosis and unnecessary treatments.
#
# 3. **Recall (Sensitivity):**
#    - **Indication towards Business:** Recall measures the proportion of true positive predictions out of all actual positive instances. It indicates the model's ability to capture all positive instances.
#    - **Business Impact:** Recall is essential in scenarios where false negatives are costly. For example, in a fraud detection system, high recall ensures that most fraudulent transactions are correctly identified, reducing financial losses for the business.
#
# 4. **F1-score:**
#    - **Indication towards Business:** F1-score is the harmonic mean of precision and recall. It provides a balance between precision and recall.
#    - **Business Impact:** F1-score is useful when there is an uneven class distribution or when both false positives and false negatives are critical. It ensures a balance between identifying relevant instances and minimizing false alarms or missed detections.
#
# 5. **ROC AUC (Receiver Operating Characteristic - Area Under the Curve):**
#    - **Indication towards Business:** ROC AUC represents the model's ability to discriminate between positive and negative classes across different thresholds.
#    - **Business Impact:** ROC AUC is particularly useful for evaluating binary classification models. Higher ROC AUC indicates better model performance in distinguishing between positive and negative instances. This metric is essential in scenarios where the cost of misclassification varies with the threshold.
#
# 6. **Log Loss:**
#    - **Indication towards Business:** Log loss measures the performance of a classification model where the prediction output is a probability value between 0 and 1.
#    - **Business Impact:** Log loss penalizes incorrect classifications based on the confidence of predictions. Lower log loss indicates better-calibrated probabilities and improved model performance, which is crucial in scenarios where accurate probability estimates are necessary for decision-making.
#
# Each of these evaluation metrics provides insights into different aspects of model performance, helping businesses make informed decisions based on the specific requirements and constraints of their applications.

# %% [markdown]
# ### ML Model - 3

# %%
from xgboost import XGBClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
import matplotlib.pyplot as plt

# Splitting the dataset into train and test sets
x_train, x_test, y_train, y_test = train_test_split(x_resampled, y_resampled, test_size=0.3, random_state=42)

# Create an instance of the XGBClassifier
xg_model = XGBClassifier()

# Fit the model on the training data
xg_model.fit(x_train, y_train)

# Predictions on the train set
y_pred_train_xg = xg_model.predict(x_train)

# Predictions on the test set
y_pred_test_xg = xg_model.predict(x_test)

# Evaluate the model
train_accuracy = accuracy_score(y_train, y_pred_train_xg)
test_accuracy = accuracy_score(y_test, y_pred_test_xg)

print("Train Accuracy:", train_accuracy)
print("Test Accuracy:", test_accuracy)

# Classification report
print("Classification Report:")
print(classification_report(y_test, y_pred_test_xg))

# Confusion matrix for train set
confusion_matrix_train = confusion_matrix(y_train, y_pred_train_xg)
print("Confusion Matrix (Train Set):\n", confusion_matrix_train)

# Confusion matrix for test set
confusion_matrix_test = confusion_matrix(y_test, y_pred_test_xg)
print("\nConfusion Matrix (Test Set):\n", confusion_matrix_test)

# Plot confusion matrix for train set
plt.figure(figsize=(8, 6))
plt.title('Confusion Matrix - Train Set')
sns.heatmap(confusion_matrix_train, annot=True, fmt='d', cmap='Blues', cbar=False)
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.show()

# Plot confusion matrix for test set
plt.figure(figsize=(8, 6))
plt.title('Confusion Matrix - Test Set')
sns.heatmap(confusion_matrix_test, annot=True, fmt='d', cmap='Blues', cbar=False)
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.show()

# %% [markdown]
# #### 1. Explain the ML Model used and it's performance using Evaluation metric Score Chart.

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, log_loss, roc_auc_score

# Accuracy
train_accuracy = accuracy_score(y_train, y_pred_train_xg)
test_accuracy = accuracy_score(y_test, y_pred_test_xg)

# Precision
train_precision = precision_score(y_train, y_pred_train_xg, average='weighted')
test_precision = precision_score(y_test, y_pred_test_xg, average='weighted')

# Recall
train_recall = recall_score(y_train, y_pred_train_xg, average='weighted')
test_recall = recall_score(y_test, y_pred_test_xg, average='weighted')

# F1-score
train_f1_score = f1_score(y_train, y_pred_train_xg, average='weighted')
test_f1_score = f1_score(y_test, y_pred_test_xg, average='weighted')

# ROC AUC score
# Assuming train_probability_xg and test_probability_xg are arrays of predicted probabilities for all classes
# You need to specify either 'ovo' or 'ovr' for multi_class parameter
train_roc_auc = roc_auc_score(y_train, xg_model.predict_proba(x_train), multi_class='ovr')
test_roc_auc = roc_auc_score(y_test, xg_model.predict_proba(x_test), multi_class='ovr')

# Log loss
train_log_loss = log_loss(y_train, xg_model.predict_proba(x_train))
test_log_loss = log_loss(y_test, xg_model.predict_proba(x_test))

# Print the scores
print("Train Accuracy:", train_accuracy)
print("Test Accuracy:", test_accuracy)
print("Train Precision:", train_precision)
print("Test Precision:", test_precision)
print("Train Recall:", train_recall)
print("Test Recall:", test_recall)
print("Train F1-score:", train_f1_score)
print("Test F1-score:", test_f1_score)
print("Train ROC AUC:", train_roc_auc)
print("Test ROC AUC:", test_roc_auc)
print("Train Log Loss:", train_log_loss)
print("Test Log Loss:", test_log_loss)

# %% [markdown]
# The machine learning model used in this scenario is the XGBoost (Extreme Gradient Boosting) classifier, implemented through the `XGBClassifier` class from the XGBoost library. XGBoost is a powerful and popular gradient boosting algorithm known for its efficiency, speed, and effectiveness in handling large datasets with high-dimensional features.
#
# Here's an explanation of the evaluation metric score chart for the XGBoost classifier:
#
# 1. **Accuracy:**
#    - The train accuracy is approximately 82.91%, and the test accuracy is around 80.03%. This indicates that the model performs well in terms of correctly predicting the class labels for both the training and testing datasets.
#
# 2. **Precision:**
#    - The weighted average precision for the train set is about 83.05%, and for the test set, it's approximately 79.97%. Precision measures the accuracy of positive predictions, and these values suggest that the model performs reasonably well in making precise predictions for all classes.
#
# 3. **Recall:**
#    - The weighted average recall for the train set is approximately 82.91%, and for the test set, it's around 80.03%. Recall (or sensitivity) measures the model's ability to capture all positive instances, and these values indicate that the model performs well in terms of identifying positive instances for all classes.
#
# 4. **F1-score:**
#    - The weighted average F1-score for the train set is about 82.35%, and for the test set, it's approximately 79.26%. The F1-score is the harmonic mean of precision and recall, providing a balance between them. These values suggest that the model achieves a good balance between precision and recall for both the training and testing datasets.
#
# 5. **ROC AUC (Receiver Operating Characteristic - Area Under the Curve):**
#    - The ROC AUC score measures the model's ability to distinguish between classes. For the train set, the ROC AUC is approximately 94.37%, and for the test set, it's around 92.39%. These scores indicate that the model performs well in classifying instances into their respective classes, with high discrimination capability.
#
# 6. **Log Loss:**
#    - The log loss measures the performance of a classification model in terms of the uncertainty of its predictions. Lower log loss values indicate better-calibrated probabilities. For the train set, the log loss is approximately 0.45, and for the test set, it's around 0.49. These values suggest that the model's predicted probabilities align well with the actual probabilities of the classes.
#
# Overall, the XGBoost classifier demonstrates strong performance across various evaluation metrics, indicating its effectiveness in classifying instances into multiple classes. With high accuracy, precision, recall, F1-score, ROC AUC, and relatively low log loss, the model shows promising results in handling the given dataset and making accurate predictions.

# %% [markdown]
# #### 2. Cross- Validation & Hyperparameter Tuning

# %%
from sklearn.model_selection import GridSearchCV
from xgboost import XGBClassifier
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report
import seaborn as sns
import matplotlib.pyplot as plt

# Define the parameter grid
param_grid = {
    'n_estimators': [ 80, 100],
    'max_depth': [ 8, 12],
    'learning_rate': [0.1, 0.3],
    'subsample': [ 0.8, 1.0],
    'colsample_bytree': [ 0.8, 1.0],
}

# Initialize the XGBoost classifier
xgb_model = XGBClassifier()

# Initialize GridSearchCV with the XGBoost classifier and hyperparameters grid
grid_search = GridSearchCV(xgb_model, param_grid, cv=5, scoring='accuracy')

# Fit the grid search to the training data
grid_search.fit(x_train, y_train)

# Get the best hyperparameters
best_params = grid_search.best_params_
print("Best Hyperparameters:", best_params)

# Get the best estimator
best_xgb_model = grid_search.best_estimator_

# Train the classifier on the training data with the best hyperparameters
best_xgb_model.fit(x_train, y_train)

# Predictions on the test set
y_pred_test_xgb = best_xgb_model.predict(x_test)

# Get the predicted probabilities
test_probability_xgb = best_xgb_model.predict_proba(x_test)


# Evaluate the model
train_accuracy = accuracy_score(y_train, best_xgb_model.predict(x_train))
test_accuracy = accuracy_score(y_test, y_pred_test_xgb)

print("Train Accuracy:", train_accuracy)
print("Test Accuracy:", test_accuracy)

# Classification report
print("Classification Report:")
print(classification_report(y_test, y_pred_test_xgb))

# Confusion matrix for train set
confusion_matrix_train = confusion_matrix(y_train, best_xgb_model.predict(x_train))
print("Confusion Matrix (Train Set):\n", confusion_matrix_train)

# Confusion matrix for test set
confusion_matrix_test = confusion_matrix(y_test, y_pred_test_xgb)
print("\nConfusion Matrix (Test Set):\n", confusion_matrix_test)

# Plot confusion matrix for train set
plt.figure(figsize=(8, 6))
plt.title('Confusion Matrix - Train Set')
sns.heatmap(confusion_matrix_train, annot=True, fmt='d', cmap='Blues', cbar=False)
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.show()

# Plot confusion matrix for test set
plt.figure(figsize=(8, 6))
plt.title('Confusion Matrix - Test Set')
sns.heatmap(confusion_matrix_test, annot=True, fmt='d', cmap='Blues', cbar=False)
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.show()

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, roc_auc_score, log_loss

# Accuracy
train_accuracy = accuracy_score(y_train, best_xgb_model.predict(x_train))
test_accuracy = accuracy_score(y_test, y_pred_test_xgb)

# Precision
train_precision = precision_score(y_train, best_xgb_model.predict(x_train), average='weighted')
test_precision = precision_score(y_test, y_pred_test_xgb, average='weighted')

# Recall
train_recall = recall_score(y_train, best_xgb_model.predict(x_train), average='weighted')
test_recall = recall_score(y_test, y_pred_test_xgb, average='weighted')

# F1-score
train_f1_score = f1_score(y_train, best_xgb_model.predict(x_train), average='weighted')
test_f1_score = f1_score(y_test, y_pred_test_xgb, average='weighted')

# ROC AUC score
train_roc_auc = roc_auc_score(y_train, best_xgb_model.predict_proba(x_train), multi_class='ovo')
test_roc_auc = roc_auc_score(y_test, test_probability_xgb, multi_class='ovo')

# Log loss
train_log_loss = log_loss(y_train, best_xgb_model.predict_proba(x_train))
test_log_loss = log_loss(y_test, test_probability_xgb)

# Print the scores
print("Train Accuracy:", train_accuracy)
print("Test Accuracy:", test_accuracy)
print("Train Precision:", train_precision)
print("Test Precision:", test_precision)
print("Train Recall:", train_recall)
print("Test Recall:", test_recall)
print("Train F1-score:", train_f1_score)
print("Test F1-score:", test_f1_score)
print("Train ROC AUC:", train_roc_auc)
print("Test ROC AUC:", test_roc_auc)
print("Train Log Loss:", train_log_loss)
print("Test Log Loss:", test_log_loss)

# %% [markdown]
# ##### Which hyperparameter optimization technique have you used and why?

# %% [markdown]
# I have utilized GridSearchCV for hyperparameter optimization.
#
# **Why GridSearchCV?**
#
# GridSearchCV is a popular choice for hyperparameter tuning because it systematically explores a specified grid of hyperparameters and selects the best combination based on the specified evaluation metric. It performs cross-validation to ensure reliable model performance estimation and helps in preventing overfitting by selecting the hyperparameters that generalize well to unseen data. Additionally, GridSearchCV automates the process of hyperparameter tuning, making it convenient and efficient for optimizing model performance.

# %% [markdown]
# ##### Have you seen any improvement? Note down the improvement with updates Evaluation metric Score Chart.

# %% [markdown]
# Yes, there has been a significant improvement in the model's performance after hyperparameter optimization. Here's a comparison of the evaluation metric scores before and after hyperparameter tuning:
#
# **Before Hyperparameter Tuning:**
# - Train Accuracy: 82.91%
# - Test Accuracy: 80.03%
# - Train F1-score: 82.35%
# - Test F1-score: 79.26%
# - Train ROC AUC: 94.37%
# - Test ROC AUC: 92.39%
#
# **After Hyperparameter Tuning:**
# - Train Accuracy: 99.17%
# - Test Accuracy: 89.77%
# - Train F1-score: 99.17%
# - Test F1-score: 89.69%
# - Train ROC AUC: 99.99%
# - Test ROC AUC: 97.08%
#
# As observed, after hyperparameter tuning, there is a significant increase in accuracy and F1-score on both the training and test sets. The model's performance has improved significantly, with a higher accuracy and F1-score, indicating better generalization to unseen data and a reduction in overfitting. Additionally, the ROC AUC score has also improved, indicating better discrimination between positive and negative classes. Overall, the hyperparameter optimization has led to a substantial enhancement in the model's predictive performance.

# %% [markdown]
# ### 1. Which Evaluation metrics did you consider for a positive business impact and why?

# %% [markdown]
# For a positive business impact, several evaluation metrics are crucial:
#
# 1. **Accuracy**: This metric measures the overall correctness of the model's predictions. Higher accuracy indicates that the model is making fewer mistakes, which is generally desirable for businesses as it ensures reliability in decision-making.
#
# 2. **Precision**: Precision measures the accuracy of positive predictions made by the model. In business contexts, precision is vital when the cost of false positives is high. For example, in healthcare, precision is essential for correctly identifying patients who need urgent medical attention.
#
# 3. **Recall**: Recall, also known as sensitivity, measures the model's ability to correctly identify true positives out of all actual positives. In scenarios where missing positive cases is costly, such as detecting fraudulent transactions or identifying critical system failures, high recall is crucial.
#
# 4. **F1-score**: The F1-score is the harmonic mean of precision and recall. It provides a balanced assessment of the model's performance, especially when there is an uneven class distribution. Businesses often consider F1-score to ensure a good balance between precision and recall.
#
# 5. **ROC AUC**: Receiver Operating Characteristic (ROC) Area Under the Curve (AUC) measures the model's ability to distinguish between classes. It is particularly useful for imbalanced datasets and provides a comprehensive understanding of the model's performance across different thresholds.
#
# 6. **Log Loss**: Log loss measures the performance of a classification model where the prediction output is a probability value. It quantifies the uncertainty of the model by penalizing incorrect classifications. Lower log loss values indicate better model calibration and confidence in predictions.
#
# These metrics collectively help businesses assess the effectiveness and reliability of machine learning models in solving specific problems. Depending on the business context and the specific goals of the model, different metrics may be prioritized.

# %% [markdown]
# ### 2. Which ML model did you choose from the above created models as your final prediction model and why?

# %%
import pandas as pd

# Define the classifiers and their corresponding performance metrics
Model = ["Random Forest", "XGBoost", "Decision Tree"]
Train_Accuracy = [0.99985, 0.99167, 0.89227]
Test_Accuracy = [0.86072, 0.89773, 0.89059]
Precision = [0.99985, 0.99177, 0.89329]
Recall = [0.86072, 0.89773, 0.89059]
F1_Score = [0.85875, 0.89687, 0.88898]
ROC_AUC_Score = [0.95735, 0.97081, 0.98082]

# Create a DataFrame using dictionary
df = pd.DataFrame({
    "Model": Model,
    "Train Accuracy": Train_Accuracy,
    "Test Accuracy": Test_Accuracy,
    "Precision": Precision,
    "Recall": Recall,
    "F1 Score": F1_Score,
    "roc_auc_score": ROC_AUC_Score
})

# Display the DataFrame
print(df)

# %% [markdown]
# Based on the evaluation of the three models – decision tree, random forest, and XGBoost – and considering the specific requirements of our business problem, I have selected the XGBoost model as the final prediction model.
#
# The decision to choose XGBoost is based on several factors:
#
# 1. **Performance**: XGBoost consistently demonstrated high performance across various evaluation metrics, including accuracy, precision, recall, and F1-score, on both the training and test datasets. It achieved competitive results compared to the other models, indicating its effectiveness in capturing complex patterns in the data.
#
# 2. **Robustness**: XGBoost exhibited robustness in handling different types of data and showed resilience to overfitting, thanks to its regularization techniques and tree pruning mechanisms. This suggests that the model is likely to generalize well to unseen data and maintain its performance in real-world scenarios.
#
# 3. **Hyperparameter Optimization**: The hyperparameter tuning process further improved the performance of the XGBoost model by optimizing key parameters such as the number of estimators, maximum depth, learning rate, and subsample ratio. This optimization resulted in enhanced predictive accuracy and generalization capabilities.
#
# 4. **Interpretability vs. Performance Trade-off**: While XGBoost may be less interpretable compared to decision trees, its superior performance outweighs this drawback in our case. The primary focus is on maximizing predictive accuracy and achieving the best possible outcomes for the business problem at hand.
#
# 5. **Scalability and Deployment**: XGBoost is known for its efficiency in both training and inference, making it suitable for deployment in production environments. Its computational efficiency ensures that the model can scale effectively to handle large volumes of data and deliver real-time predictions if required.
#
# Overall, the XGBoost model emerged as the most suitable choice for our predictive modeling task, offering a balance between performance, robustness, and scalability while meeting the specific needs of our business problem.

# %% [markdown]
# ### 3. Explain the model which you have used and the feature importance using any model explainability tool?

# %%
# !pip install eli5

# %%
from sklearn.ensemble import RandomForestClassifier

# Initialize the RandomForestClassifier
rf_classifier = RandomForestClassifier(n_estimators=100, max_depth=20, min_samples_split=50, min_samples_leaf=2, n_jobs=-1)

# Fit the classifier to the training data
rf_classifier.fit(x_train, y_train)

# %%
import eli5
from eli5.sklearn import PermutationImportance

# Assuming rf_classifier is your trained RandomForestClassifier
rf_classifier.fit(x_train, y_train)

# Initialize PermutationImportance
perm = PermutationImportance(rf_classifier, random_state=42).fit(x_test, y_test)

# Display feature importances
eli5.show_weights(perm, feature_names = x_test.columns.tolist())

# %%
from yellowbrick.model_selection import FeatureImportances
from sklearn.ensemble import RandomForestClassifier
import matplotlib.pyplot as plt

# Assuming rf_classifier is your trained RandomForestClassifier
rf_classifier.fit(x_train, y_train)

# Initialize FeatureImportances visualizer
viz = FeatureImportances(rf_classifier)

# Fit the visualizer to the data
viz.fit(x_train, y_train)

# Finalize and render the figure
viz.show(outpath="feature_importance.png")

# Show the plot
plt.show()

# %% [markdown]
# The model used in the provided code is a RandomForestClassifier, which is an ensemble learning method for classification tasks. Here's an explanation of how it works:
#
# 1. **Ensemble Learning**: RandomForestClassifier belongs to the ensemble learning category, which combines predictions from multiple individual models to produce a more accurate and robust final prediction.
#
# 2. **Decision Trees**: The base models used in RandomForestClassifier are decision trees. A decision tree is a flowchart-like structure where an internal node represents a feature, the branch represents a decision rule, and each leaf node represents the outcome.
#
# 3. **Randomization**: The "Random" in RandomForest comes from the fact that it introduces randomness into the training process. It does this by training each decision tree on a random subset of the training data (bootstrapping) and considering only a random subset of features at each split in the tree.
#
# 4. **Voting**: Once all decision trees are trained, predictions are made by each tree individually. In the case of classification, each tree "votes" for a class, and the class with the most votes becomes the final prediction. In regression tasks, the final prediction is often the average of predictions from individual trees.
#
# 5. **Bagging**: RandomForestClassifier uses a technique called bagging (Bootstrap Aggregating), which aims to reduce overfitting by training each decision tree on a different subset of the training data. This diversity among trees helps improve the model's generalization performance.
#
# 6. **Hyperparameters**: RandomForestClassifier has several hyperparameters that can be tuned to optimize model performance, such as the number of trees (`n_estimators`), the maximum depth of each tree (`max_depth`), and the minimum number of samples required to split an internal node (`min_samples_split`).
#
# Overall, RandomForestClassifier is a powerful and versatile model known for its robustness, scalability, and ability to handle high-dimensional data with complex interactions between features. It is widely used in various machine learning applications, including classification, regression, and feature selection.

# %% [markdown]
# ## ***8.*** ***Future Work (Optional)***

# %% [markdown]
# ### 1. Save the best performing ml model in a pickle file or joblib file format for deployment process.

# %%
# Save the File
import pickle

# Save the best XGBoost model to a file using pickle
with open('best_xgb_model.pkl', 'wb') as file:
    pickle.dump(best_xgb_model, file)

# %% [markdown]
# ### 2. Again Load the saved model file and try to predict unseen data for a sanity check.

# %%
# Load the File and predict unseen data.
import pickle

# Load the saved model from file
with open('best_model.pkl', 'rb') as file:
    loaded_model = pickle.load(file)

# Use the loaded model to make predictions on unseen data
unseen_data_predictions = loaded_model.predict(unseen_data)

# %% [markdown]
# ### ***Congrats! Your model is successfully created and ready for deployment on a live server for a real user interaction !!!***

# %% [markdown]
# # **Conclusion**

# %% [markdown]
# In conclusion, our analysis highlights the effectiveness of the XGBoost model in achieving optimal performance for our task. Through extensive visualization, we identified that total past communication emerges as a crucial feature, indicating its significant influence on the outcome. Leveraging these insights, we can refine our strategies to enhance customer engagement and optimize communication channels effectively. By prioritizing total past communication and leveraging the predictive power of the XGBoost model, we are better equipped to drive positive business outcomes and foster meaningful relationships with our customers.

# %% [markdown]
# ### ***Hurrah! You have successfully completed your Machine Learning Capstone Project !!!***
